# %%
import sys
from pathlib import Path
sys.path.append(Path("../..").resolve())

# %%
from pathlib import Path

tree_dir = Path( "../../data/treeObjs/xhem/data")
treeFileName = "tree_2017_lb18145-35.pkl"
tree =
