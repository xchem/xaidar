# %%
import sys
from pathlib import Path
sys.path.insert( 0, Path( "../..").absolute() )

# %%
from xaidar.filesUtils import loadPickle

treeFile = loadPickle( Path("../../data/treeObjs/xchem/data/tree_2017_lb13385-110.pkl") )
print(treeFile.keys() )
# Out:
# dict_keys(['fileTree', 'folderTree', 'folderTreeMaxDepth', ' foldersIDS', 'foldersCount', 'foldersLst'])

# %%
from xaidar.treeclass import loadTree

tree = loadTree( Path("../../data/treeObjs/xchem/data/tree_2017_lb13385-110.pkl")  )

# %%
tree.viewTree( itemID = [0, 0, 0, 1, 0] )
# Out:
# data
# └── 2017
#     └── lb13385-110
#         └── processing
#             └── database
#                 ├── [0] DataFileBackups
#                 └── [1-f] soakDBDataFile.sqlite
