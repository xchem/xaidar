# %% [markdown]
# This notebook consists extracting the data of interest for this project into the `data/ev2a` folder before starting to work with it.
#
# Tasks:
# - Identify projects and sessions with `ev2a` as part of their datasets.

# %%
# Check current path 
from pathlib import Path
print( Path(".").absolute() )
# Out:
# /dls/science/groups/i04-1/software/xchem-data-enjoyers/alex-belo/xaidar/notebooks/tasks/ev2a

# %%
import re
# regex library

regex_dict = { "proj":  "^[a-zA-Z][a-zA-Z][0-9]+$",
              "sesh": "^[a-zA-Z][a-zA-Z][0-9]+-[0-9]+$",
               "dataset": "^[a-zA-Z0-9]+-[a-zA-Z0-9]+[0-9]+$",
                "protID": "^[a-zA-Z0-9]+-" }

# %% [markdown]
# ---

# %% [markdown]
# ## Toy Example

# %%
# Get example directory

#  seshPath = "/dls/labxchem/data/lb32627/lb32627-66"

projPath = Path( "/dls/labxchem/data/lb32627" )
print( projPath )
print( projPath.exists())
print( list(projPath.iterdir()))
# Out:
# /dls/labxchem/data/lb32627
# True
# [PosixPath('/dls/labxchem/data/lb32627/lb32627-66'), PosixPath('/dls/labxchem/data/lb32627/lb32627-65'), PosixPath('/dls/labxchem/data/lb32627/lb32627-67'), PosixPath('/dls/labxchem/data/lb32627/lb32627-78'), PosixPath('/dls/labxchem/data/lb32627/lb32627-9'), PosixPath('/dls/labxchem/data/lb32627/lb32627-593'), PosixPath('/dls/labxchem/data/lb32627/lb32627-567'), PosixPath('/dls/labxchem/data/lb32627/lb32627-268'), PosixPath('/dls/labxchem/data/lb32627/lb32627-369'), PosixPath('/dls/labxchem/data/lb32627/lb32627-352'), PosixPath('/dls/labxchem/data/lb32627/lb32627-93'), PosixPath('/dls/labxchem/data/lb32627/lb32627-76'), PosixPath('/dls/labxchem/data/lb32627/lb32627-77'), PosixPath('/dls/labxchem/data/lb32627/lb32627-5'), PosixPath('/dls/labxchem/data/lb32627/lb32627-71'), PosixPath('/dls/labxchem/data/lb32627/lb32627-370'), PosixPath('/dls/labxchem/data/lb32627/lb32627-272'), PosixPath('/dls/labxchem/data/lb32627/lb32627-32'), PosixPath('/dls/labxchem/data/lb32627/lb32627-384'), PosixPath('/dls/labxchem/data/lb32627/lb32627-22'), PosixPath('/dls/labxchem/data/lb32627/lb32627-154'), PosixPath('/dls/labxchem/data/lb32627/lb32627-1'), PosixPath('/dls/labxchem/data/lb32627/lb32627-2'), PosixPath('/dls/labxchem/data/lb32627/lb32627-6'), PosixPath('/dls/labxchem/data/lb32627/lb32627-261'), PosixPath('/dls/labxchem/data/lb32627/lb32627-406'), PosixPath('/dls/labxchem/data/lb32627/lb32627-47')]

# %%
import re
sesh = "A71EV2A-x1876"
re.search( "^[0-9a-zA-Z]+", sesh).group()
# Out:
# 'A71EV2A'

# %%
data = set()

data.update([1,2,2])
print( data )
# Out:
# {1, 2}

# %%
import re
lst_sessions = list(projPath.iterdir())
print(lst_sessions)
dict_sessions = dict()
set_datasets = set()
for session in projPath.iterdir():
    datasetsPath = session / "processing/analysis/model_building"
    if datasetsPath.exists():
        dict_sessions[session.name] = list( datasetsPath.iterdir())
        lst_datasets = [re.search(  "^[0-9a-zA-Z]+", dataset.name ).group() for dataset in datasetsPath.iterdir() 
                         if re.search(  "^[0-9a-zA-Z]+", dataset.name )]
        set_datasets.update( lst_datasets )
    else:
        dict_sessions[session.name] = None




# "/dls/labxchem/data/lb32627/lb32627-66/processing/analysis/model_building/"
# Out:
# [PosixPath('/dls/labxchem/data/lb32627/lb32627-66'), PosixPath('/dls/labxchem/data/lb32627/lb32627-65'), PosixPath('/dls/labxchem/data/lb32627/lb32627-67'), PosixPath('/dls/labxchem/data/lb32627/lb32627-78'), PosixPath('/dls/labxchem/data/lb32627/lb32627-9'), PosixPath('/dls/labxchem/data/lb32627/lb32627-593'), PosixPath('/dls/labxchem/data/lb32627/lb32627-567'), PosixPath('/dls/labxchem/data/lb32627/lb32627-268'), PosixPath('/dls/labxchem/data/lb32627/lb32627-369'), PosixPath('/dls/labxchem/data/lb32627/lb32627-352'), PosixPath('/dls/labxchem/data/lb32627/lb32627-93'), PosixPath('/dls/labxchem/data/lb32627/lb32627-76'), PosixPath('/dls/labxchem/data/lb32627/lb32627-77'), PosixPath('/dls/labxchem/data/lb32627/lb32627-5'), PosixPath('/dls/labxchem/data/lb32627/lb32627-71'), PosixPath('/dls/labxchem/data/lb32627/lb32627-370'), PosixPath('/dls/labxchem/data/lb32627/lb32627-272'), PosixPath('/dls/labxchem/data/lb32627/lb32627-32'), PosixPath('/dls/labxchem/data/lb32627/lb32627-384'), PosixPath('/dls/labxchem/data/lb32627/lb32627-22'), PosixPath('/dls/labxchem/data/lb32627/lb32627-154'), PosixPath('/dls/labxchem/data/lb32627/lb32627-1'), PosixPath('/dls/labxchem/data/lb32627/lb32627-2'), PosixPath('/dls/labxchem/data/lb32627/lb32627-6'), PosixPath('/dls/labxchem/data/lb32627/lb32627-261'), PosixPath('/dls/labxchem/data/lb32627/lb32627-406'), PosixPath('/dls/labxchem/data/lb32627/lb32627-47')]

# %%
print( set_datasets)
print( [ key for key, value in dict_sessions.items() if value == None] )
print( [ key for key, value in dict_sessions.items() if value != None] )
print( len(set_datasets) , len( [ key for key, value in dict_sessions.items() if value != None]))
# Out:
# {'refine', 'attic', 'A71EV2AZ', 'A71EV2A', '7da6', 'mmcif', 'D68EV3CPROB', 'A71EV2AC110A', 'QQ01D2VNS2BA', 'model', 'XX01ZVNS2BA', '4fvd', 'XX01D2VNS2BA', 'Zika', 'MERS', 'MS', 'xce', 'SARS2', 'XX01ZVNS2B'}
# ['lb32627-9', 'lb32627-593', 'lb32627-76', 'lb32627-5', 'lb32627-32', 'lb32627-22', 'lb32627-154', 'lb32627-1', 'lb32627-6', 'lb32627-47']
# ['lb32627-66', 'lb32627-65', 'lb32627-67', 'lb32627-78', 'lb32627-567', 'lb32627-268', 'lb32627-369', 'lb32627-352', 'lb32627-93', 'lb32627-77', 'lb32627-71', 'lb32627-370', 'lb32627-272', 'lb32627-384', 'lb32627-2', 'lb32627-261', 'lb32627-406']
# 19 17

# %% [markdown]
# ---

# %% [markdown]
# ## ID Folders with EV2A datasets
# ###  Generalize

# %%
# Get generator for root dir
from pathlib import Path
import re
rootDir = Path("/dls/labxchem/data")

projRegex = re.compile( regex_dict["proj"])
seshRegex = re.compile( regex_dict["sesh"])
datasetRegex = re.compile( regex_dict["dataset"])
protIDRegex =  re.compile( regex_dict["protID"])
matches = []

for proj in 

# for path in rootDir.joinpath( "lb32627").rglob( "*"):
#     if datasetRegex.match(path.name):
#         matches.append( {"proj": dataset.parents[-5].name,
#                          "sesh": dataset.parents[-6].name,
#                          "protID": re.match("^[a-zA-Z0-9]+-", )})

# %%
from pathlib import Path

path = Path( ".").resolve()
path.as_posix()
# Out:
# '/dls/science/groups/i04-1/software/xchem-data-enjoyers/alex-belo/xaidar/notebooks/tasks/ev2a'

# %%
rootDir = Path("/dls/labxchem/data/proj/sesh")
rootDir.parents[-5].name
# Out:
# 'proj'

# %%
from pathlib import Path

rootDir = Path("/dls/labxchem/data")
rootDir.is_dir()
rootDir.joinpath( "sesh" ).exists()
# Out:
# False

# %%
import re
from pathlib import Path

# Gemini
def find_paths_with_regex(root_path: Path, regex_patterns):
    """
    Finds files and folders that match a sequence of regular expressions for each path level.

    Args:
        root_path (str): The absolute or relative path to start the search from.
        regex_patterns (list): A list of regex pattern strings. Each pattern corresponds
                               to a directory/file level in the path.

    Returns:
        list: A list of full paths that match the entire sequence of regex patterns.
              Returns an empty list if the root_path does not exist.
    """
    if not root_path.is_dir():
        print(f"Error: Root path '{root_path}' does not exist or is not a directory.")
        return []

    # This is the recursive helper function that does the actual work.
    def _find_recursive(current_path, patterns):
        # If there are no more patterns to match, we have successfully found a complete match.
        if not patterns:
            return [current_path]

        found_paths = []
        current_pattern = patterns[0]
        remaining_patterns = patterns[1:]

        # Handle the deep search wildcard '**'
        is_glob_tuple = isinstance(current_pattern, (list, tuple)) and \
                        len(current_pattern) > 0 and current_pattern[0] == '**'

        if current_pattern == '**' or is_glob_tuple:
            # Set defaults for min/max depth. '**' is equivalent to (**, 0, infinity)
            min_depth = 0
            max_depth = float('inf')
            
            if is_glob_tuple:
                # Syntax: ('**', min) or ('**', min, max)
                if len(current_pattern) > 2:
                    min_depth = current_pattern[1]
                    max_depth = current_pattern[2]
                elif len(current_pattern) > 1:
                    min_depth = current_pattern[1]

            # # If '**' is the last pattern, find all descendants within depth constraints.
            # if not remaining_patterns:
            #     if not current_path.is_dir(): return []
                
            #     found = []
            #     # Queue stores (path_object, depth_from_current_path)
            #     queue = [(p, 1) for p in current_path.iterdir()]
                
            #     while queue:
            #         item, depth = queue.pop(0)
                    
            #         if depth >= min_depth:
            #             found.append(str(item))
                    
            #         if depth < max_depth and item.is_dir():
            #             for child in item.iterdir():
            #                 queue.append((child, depth + 1))
            #     return found

            # If '**' is followed by another pattern, search for it within the depth constraints.
            next_pattern = remaining_patterns[0]
            patterns_after_next = remaining_patterns[1:]
            next_regex = re.compile(next_pattern)
            
            if not current_path.is_dir(): return []

            # BFS queue stores (path_to_scan, current_depth)
            queue = [(current_path, 0)]

            while queue:
                path_to_scan, depth = queue.pop(0)

                # At valid depths, check children for the next pattern
                if depth >= min_depth:
                    for child in path_to_scan.iterdir():
                        if next_regex.match(child.name):
                            found_paths.extend(_find_recursive(child, patterns_after_next))
                
                # If we can go deeper, add subdirectories to the queue
                if depth < max_depth:
                    for child in path_to_scan.iterdir():
                        if child.is_dir():
                            queue.append((child, depth + 1))
            
            return found_paths


        # --- Standard logic for a single-level regex pattern ---

        # We can only search inside directories.
        if not current_path.is_dir():
            return []

        try:
            # Compile the regex for efficiency.
            regex = re.compile(current_pattern)
            
            # List all items in the current directory.
            for entry in current_path.iterdir():
                # If the current item's name matches the pattern for this level...
                if regex.match(entry.name):
                    full_path = current_path.joinpath( entry.name )
                    
                    # If this was the last pattern, we have a final match.
                    if not remaining_patterns:
                        found_paths.append(full_path)
                    # Otherwise, continue searching deeper into the directory structure.
                    else:
                        # Recursively call the function for the next level down.
                        found_paths.extend(_find_recursive(full_path, remaining_patterns))
        except OSError as e:
            # Handle cases where we might not have permission to read a directory.
            print(f"Could not access {current_path}: {e}")
        
        return found_paths

    # Start the recursive search from the root path with the initial patterns.
    return _find_recursive(root_path, regex_patterns)

# %%
rootPath = Path( "/dls/labxchem/data" )


regex_dict = { "proj":  "^[a-zA-Z][a-zA-Z][0-9]+$",
              "sesh": "^[a-zA-Z][a-zA-Z][0-9]+-[0-9]+$",
               "dataset": "^[a-zA-Z0-9]+-[a-zA-Z0-9]+[0-9]+$",
                "protID": "^[a-zA-Z0-9]+-" }


regex_Lst = [ regex_dict["proj"], regex_dict["sesh"]]



projects = find_paths_with_regex(rootPath, [ regex_dict["proj"] ])
sessions = find_paths_with_regex(rootPath,  [ regex_dict["proj"], regex_dict["sesh"] ]  )

print( f"Number of projects: {len( projects)}")
print( f"Number of sessions: {len(sessions)}")
print( projects[:4])
print( projects[-4:])
# Out:
# Number of projects: 141
# Number of sessions: 677
# [PosixPath('/dls/labxchem/data/sw35836'), PosixPath('/dls/labxchem/data/sw35738'), PosixPath('/dls/labxchem/data/sw27229'), PosixPath('/dls/labxchem/data/lb27001')]
# [PosixPath('/dls/labxchem/data/sw41075'), PosixPath('/dls/labxchem/data/sw32701'), PosixPath('/dls/labxchem/data/lb30602'), PosixPath('/dls/labxchem/data/lb28724')]

# %%
# /dls/labxchem/data/lb32627/lb32627-66
data = Path("/dls/labxchem/data")

# results = find_paths_with_regex(data,[ "^lb32627$", ("**", 2, 5), regex_dict["dataset"]] )

results = find_paths_with_regex( data,[ regex_dict["proj"], regex_dict["sesh"], "processing", "analysis", "model_building", regex_dict["dataset"]] )
# Out:
# Could not access /dls/labxchem/data/sw35836/sw35836-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw35836/sw35836-9'
# Could not access /dls/labxchem/data/sw35836/sw35836-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw35836/sw35836-7'
# Could not access /dls/labxchem/data/sw35836/sw35836-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw35836/sw35836-3'
# Could not access /dls/labxchem/data/sw35836/sw35836-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw35836/sw35836-5'
# Could not access /dls/labxchem/data/sw35836/sw35836-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw35836/sw35836-6'
# Could not access /dls/labxchem/data/sw35836/sw35836-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw35836/sw35836-1'
# Could not access /dls/labxchem/data/sw35738/sw35738-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw35738/sw35738-5'
# Could not access /dls/labxchem/data/sw35738/sw35738-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw35738/sw35738-1'
# Could not access /dls/labxchem/data/sw35738/sw35738-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw35738/sw35738-9'
# Could not access /dls/labxchem/data/sw35738/sw35738-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw35738/sw35738-7'
# Could not access /dls/labxchem/data/sw35738/sw35738-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw35738/sw35738-3'
# Could not access /dls/labxchem/data/lb27001/lb27001-39: [Errno 13] Permission denied: '/dls/labxchem/data/lb27001/lb27001-39'
# Could not access /dls/labxchem/data/sw42482/sw42482-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw42482/sw42482-1'
# Could not access /dls/labxchem/data/sw42482/sw42482-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw42482/sw42482-3'
# Could not access /dls/labxchem/data/sw42482/sw42482-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw42482/sw42482-5'
# Could not access /dls/labxchem/data/sw40896/sw40896-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw40896/sw40896-5'
# Could not access /dls/labxchem/data/sw40896/sw40896-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw40896/sw40896-3'
# Could not access /dls/labxchem/data/sw40896/sw40896-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw40896/sw40896-6'
# Could not access /dls/labxchem/data/sw40896/sw40896-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw40896/sw40896-1'
# Could not access /dls/labxchem/data/lb36049/lb36049-13: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-13'
# Could not access /dls/labxchem/data/lb36049/lb36049-14: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-14'
# Could not access /dls/labxchem/data/lb36049/lb36049-54: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-54'
# Could not access /dls/labxchem/data/lb36049/lb36049-33: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-33'
# Could not access /dls/labxchem/data/lb36049/lb36049-67: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-67'
# Could not access /dls/labxchem/data/lb36049/lb36049-39: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-39'
# Could not access /dls/labxchem/data/lb36049/lb36049-3: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-3'
# Could not access /dls/labxchem/data/lb36049/lb36049-4: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-4'
# Could not access /dls/labxchem/data/lb36049/lb36049-15: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-15'
# Could not access /dls/labxchem/data/lb36049/lb36049-55: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-55'
# Could not access /dls/labxchem/data/lb36049/lb36049-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-1'
# Could not access /dls/labxchem/data/lb36049/lb36049-40: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-40'
# Could not access /dls/labxchem/data/lb36049/lb36049-2: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-2'
# Could not access /dls/labxchem/data/lb36049/lb36049-64: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-64'
# Could not access /dls/labxchem/data/lb36049/lb36049-7: [Errno 13] Permission denied: '/dls/labxchem/data/lb36049/lb36049-7'
# Could not access /dls/labxchem/data/sw37454/sw37454-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw37454/sw37454-3'
# Could not access /dls/labxchem/data/sw37454/sw37454-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw37454/sw37454-5'
# Could not access /dls/labxchem/data/sw37454/sw37454-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw37454/sw37454-9'
# Could not access /dls/labxchem/data/sw37454/sw37454-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw37454/sw37454-7'
# Could not access /dls/labxchem/data/sw37454/sw37454-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw37454/sw37454-1'
# Could not access /dls/labxchem/data/lb35305/lb35305-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb35305/lb35305-1'
# Could not access /dls/labxchem/data/lb29209/lb29209-22: [Errno 13] Permission denied: '/dls/labxchem/data/lb29209/lb29209-22'
# Could not access /dls/labxchem/data/lb29209/lb29209-7: [Errno 13] Permission denied: '/dls/labxchem/data/lb29209/lb29209-7'
# Could not access /dls/labxchem/data/lb29209/lb29209-6: [Errno 13] Permission denied: '/dls/labxchem/data/lb29209/lb29209-6'
# Could not access /dls/labxchem/data/sw40810/sw40810-4: [Errno 13] Permission denied: '/dls/labxchem/data/sw40810/sw40810-4'
# Could not access /dls/labxchem/data/sw40810/sw40810-2: [Errno 13] Permission denied: '/dls/labxchem/data/sw40810/sw40810-2'
# Could not access /dls/labxchem/data/sw40810/sw40810-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw40810/sw40810-1'
# Could not access /dls/labxchem/data/lb37031/lb37031-5: [Errno 13] Permission denied: '/dls/labxchem/data/lb37031/lb37031-5'
# Could not access /dls/labxchem/data/lb37031/lb37031-3: [Errno 13] Permission denied: '/dls/labxchem/data/lb37031/lb37031-3'
# Could not access /dls/labxchem/data/lb37031/lb37031-25: [Errno 13] Permission denied: '/dls/labxchem/data/lb37031/lb37031-25'
# Could not access /dls/labxchem/data/lb37031/lb37031-26: [Errno 13] Permission denied: '/dls/labxchem/data/lb37031/lb37031-26'
# Could not access /dls/labxchem/data/lb37031/lb37031-17: [Errno 13] Permission denied: '/dls/labxchem/data/lb37031/lb37031-17'
# Could not access /dls/labxchem/data/lb37031/lb37031-19: [Errno 13] Permission denied: '/dls/labxchem/data/lb37031/lb37031-19'
# Could not access /dls/labxchem/data/lb37031/lb37031-18: [Errno 13] Permission denied: '/dls/labxchem/data/lb37031/lb37031-18'
# Could not access /dls/labxchem/data/lb37031/lb37031-4: [Errno 13] Permission denied: '/dls/labxchem/data/lb37031/lb37031-4'
# Could not access /dls/labxchem/data/lb37031/lb37031-31: [Errno 13] Permission denied: '/dls/labxchem/data/lb37031/lb37031-31'
# Could not access /dls/labxchem/data/lb37031/lb37031-12: [Errno 13] Permission denied: '/dls/labxchem/data/lb37031/lb37031-12'
# Could not access /dls/labxchem/data/lb37031/lb37031-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb37031/lb37031-1'
# Could not access /dls/labxchem/data/lb37031/lb37031-2: [Errno 13] Permission denied: '/dls/labxchem/data/lb37031/lb37031-2'
# Could not access /dls/labxchem/data/lb37026/lb37026-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb37026/lb37026-1'
# Could not access /dls/labxchem/data/lb37026/lb37026-5: [Errno 13] Permission denied: '/dls/labxchem/data/lb37026/lb37026-5'
# Could not access /dls/labxchem/data/lb37026/lb37026-6: [Errno 13] Permission denied: '/dls/labxchem/data/lb37026/lb37026-6'
# Could not access /dls/labxchem/data/lb37026/lb37026-2: [Errno 13] Permission denied: '/dls/labxchem/data/lb37026/lb37026-2'
# Could not access /dls/labxchem/data/lb37026/lb37026-7: [Errno 13] Permission denied: '/dls/labxchem/data/lb37026/lb37026-7'
# Could not access /dls/labxchem/data/lb37026/lb37026-8: [Errno 13] Permission denied: '/dls/labxchem/data/lb37026/lb37026-8'
# Could not access /dls/labxchem/data/lb18145/lb18145-257: [Errno 13] Permission denied: '/dls/labxchem/data/lb18145/lb18145-257'
# Could not access /dls/labxchem/data/lb18145/lb18145-259: [Errno 13] Permission denied: '/dls/labxchem/data/lb18145/lb18145-259'
# Could not access /dls/labxchem/data/lb18145/lb18145-271: [Errno 13] Permission denied: '/dls/labxchem/data/lb18145/lb18145-271'
# Could not access /dls/labxchem/data/lb18145/lb18145-260: [Errno 13] Permission denied: '/dls/labxchem/data/lb18145/lb18145-260'
# Could not access /dls/labxchem/data/lb18145/lb18145-272: [Errno 13] Permission denied: '/dls/labxchem/data/lb18145/lb18145-272'
# Could not access /dls/labxchem/data/lb18145/lb18145-262: [Errno 13] Permission denied: '/dls/labxchem/data/lb18145/lb18145-262'
# Could not access /dls/labxchem/data/lb18145/lb18145-269: [Errno 13] Permission denied: '/dls/labxchem/data/lb18145/lb18145-269'
# Could not access /dls/labxchem/data/lb18145/lb18145-274: [Errno 13] Permission denied: '/dls/labxchem/data/lb18145/lb18145-274'
# Could not access /dls/labxchem/data/lb18145/lb18145-273: [Errno 13] Permission denied: '/dls/labxchem/data/lb18145/lb18145-273'
# Could not access /dls/labxchem/data/lb18145/lb18145-263: [Errno 13] Permission denied: '/dls/labxchem/data/lb18145/lb18145-263'
# Could not access /dls/labxchem/data/lb18145/lb18145-266: [Errno 13] Permission denied: '/dls/labxchem/data/lb18145/lb18145-266'
# Could not access /dls/labxchem/data/lb18145/lb18145-258: [Errno 13] Permission denied: '/dls/labxchem/data/lb18145/lb18145-258'
# Could not access /dls/labxchem/data/sw36321/sw36321-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw36321/sw36321-1'
# Could not access /dls/labxchem/data/sw28514/sw28514-34: [Errno 13] Permission denied: '/dls/labxchem/data/sw28514/sw28514-34'
# Could not access /dls/labxchem/data/sw28514/sw28514-26: [Errno 13] Permission denied: '/dls/labxchem/data/sw28514/sw28514-26'
# Could not access /dls/labxchem/data/sw28514/sw28514-28: [Errno 13] Permission denied: '/dls/labxchem/data/sw28514/sw28514-28'
# Could not access /dls/labxchem/data/sw28514/sw28514-33: [Errno 13] Permission denied: '/dls/labxchem/data/sw28514/sw28514-33'
# Could not access /dls/labxchem/data/sw28514/sw28514-30: [Errno 13] Permission denied: '/dls/labxchem/data/sw28514/sw28514-30'
# Could not access /dls/labxchem/data/sw40872/sw40872-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw40872/sw40872-6'
# Could not access /dls/labxchem/data/sw40872/sw40872-2: [Errno 13] Permission denied: '/dls/labxchem/data/sw40872/sw40872-2'
# Could not access /dls/labxchem/data/sw40872/sw40872-4: [Errno 13] Permission denied: '/dls/labxchem/data/sw40872/sw40872-4'
# Could not access /dls/labxchem/data/sw35810/sw35810-8: [Errno 13] Permission denied: '/dls/labxchem/data/sw35810/sw35810-8'
# Could not access /dls/labxchem/data/sw35810/sw35810-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw35810/sw35810-7'
# Could not access /dls/labxchem/data/sw35810/sw35810-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw35810/sw35810-3'
# Could not access /dls/labxchem/data/sw35810/sw35810-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw35810/sw35810-1'
# Could not access /dls/labxchem/data/sw35810/sw35810-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw35810/sw35810-5'
# Could not access /dls/labxchem/data/sw39339/sw39339-11: [Errno 13] Permission denied: '/dls/labxchem/data/sw39339/sw39339-11'
# Could not access /dls/labxchem/data/sw39339/sw39339-13: [Errno 13] Permission denied: '/dls/labxchem/data/sw39339/sw39339-13'
# Could not access /dls/labxchem/data/sw39339/sw39339-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw39339/sw39339-7'
# Could not access /dls/labxchem/data/sw39339/sw39339-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw39339/sw39339-5'
# Could not access /dls/labxchem/data/sw39339/sw39339-8: [Errno 13] Permission denied: '/dls/labxchem/data/sw39339/sw39339-8'
# Could not access /dls/labxchem/data/sw39339/sw39339-17: [Errno 13] Permission denied: '/dls/labxchem/data/sw39339/sw39339-17'
# Could not access /dls/labxchem/data/sw39339/sw39339-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw39339/sw39339-1'
# Could not access /dls/labxchem/data/sw39339/sw39339-14: [Errno 13] Permission denied: '/dls/labxchem/data/sw39339/sw39339-14'
# Could not access /dls/labxchem/data/sw39339/sw39339-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw39339/sw39339-3'
# Could not access /dls/labxchem/data/lb30671/lb30671-5: [Errno 13] Permission denied: '/dls/labxchem/data/lb30671/lb30671-5'
# Could not access /dls/labxchem/data/lb36626/lb36626-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb36626/lb36626-1'
# Could not access /dls/labxchem/data/sw35571/sw35571-10: [Errno 13] Permission denied: '/dls/labxchem/data/sw35571/sw35571-10'
# Could not access /dls/labxchem/data/sw35571/sw35571-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw35571/sw35571-5'
# Could not access /dls/labxchem/data/sw35571/sw35571-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw35571/sw35571-1'
# Could not access /dls/labxchem/data/sw35396/sw35396-18: [Errno 13] Permission denied: '/dls/labxchem/data/sw35396/sw35396-18'
# Could not access /dls/labxchem/data/sw35396/sw35396-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw35396/sw35396-3'
# Could not access /dls/labxchem/data/sw35396/sw35396-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw35396/sw35396-7'
# Could not access /dls/labxchem/data/sw35396/sw35396-10: [Errno 13] Permission denied: '/dls/labxchem/data/sw35396/sw35396-10'
# Could not access /dls/labxchem/data/sw35396/sw35396-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw35396/sw35396-1'
# Could not access /dls/labxchem/data/sw35396/sw35396-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw35396/sw35396-9'
# Could not access /dls/labxchem/data/sw35396/sw35396-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw35396/sw35396-5'
# Could not access /dls/labxchem/data/sw35396/sw35396-12: [Errno 13] Permission denied: '/dls/labxchem/data/sw35396/sw35396-12'
# Could not access /dls/labxchem/data/sw35382/sw35382-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw35382/sw35382-6'
# Could not access /dls/labxchem/data/sw35382/sw35382-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw35382/sw35382-5'
# Could not access /dls/labxchem/data/sw35382/sw35382-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw35382/sw35382-3'
# Could not access /dls/labxchem/data/sw35382/sw35382-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw35382/sw35382-1'
# Could not access /dls/labxchem/data/lb33185/lb33185-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb33185/lb33185-1'
# Could not access /dls/labxchem/data/lb39510/lb39510-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb39510/lb39510-1'
# Could not access /dls/labxchem/data/lb37866/lb37866-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb37866/lb37866-1'
# Could not access /dls/labxchem/data/sw37153/sw37153-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw37153/sw37153-3'
# Could not access /dls/labxchem/data/sw37153/sw37153-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw37153/sw37153-5'
# Could not access /dls/labxchem/data/sw37153/sw37153-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw37153/sw37153-7'
# Could not access /dls/labxchem/data/sw37153/sw37153-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw37153/sw37153-1'
# Could not access /dls/labxchem/data/lb39490/lb39490-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb39490/lb39490-1'
# Could not access /dls/labxchem/data/lb39490/lb39490-2: [Errno 13] Permission denied: '/dls/labxchem/data/lb39490/lb39490-2'
# Could not access /dls/labxchem/data/sw38817/sw38817-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw38817/sw38817-5'
# Could not access /dls/labxchem/data/sw38817/sw38817-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw38817/sw38817-3'
# Could not access /dls/labxchem/data/sw38817/sw38817-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw38817/sw38817-1'
# Could not access /dls/labxchem/data/sw37071/sw37071-4: [Errno 13] Permission denied: '/dls/labxchem/data/sw37071/sw37071-4'
# Could not access /dls/labxchem/data/sw37071/sw37071-12: [Errno 13] Permission denied: '/dls/labxchem/data/sw37071/sw37071-12'
# Could not access /dls/labxchem/data/sw37071/sw37071-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw37071/sw37071-1'
# Could not access /dls/labxchem/data/sw37071/sw37071-8: [Errno 13] Permission denied: '/dls/labxchem/data/sw37071/sw37071-8'
# Could not access /dls/labxchem/data/sw37071/sw37071-10: [Errno 13] Permission denied: '/dls/labxchem/data/sw37071/sw37071-10'
# Could not access /dls/labxchem/data/sw37071/sw37071-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw37071/sw37071-6'
# Could not access /dls/labxchem/data/sw37071/sw37071-2: [Errno 13] Permission denied: '/dls/labxchem/data/sw37071/sw37071-2'
# Could not access /dls/labxchem/data/sw37071/sw37071-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw37071/sw37071-9'
# Could not access /dls/labxchem/data/sw40506/sw40506-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw40506/sw40506-1'
# Could not access /dls/labxchem/data/sw40506/sw40506-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw40506/sw40506-3'
# Could not access /dls/labxchem/data/sw40506/sw40506-2: [Errno 13] Permission denied: '/dls/labxchem/data/sw40506/sw40506-2'
# Could not access /dls/labxchem/data/lb35307/lb35307-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb35307/lb35307-1'
# Could not access /dls/labxchem/data/sw36193/sw36193-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw36193/sw36193-1'
# Could not access /dls/labxchem/data/sw36193/sw36193-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw36193/sw36193-5'
# Could not access /dls/labxchem/data/sw36193/sw36193-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw36193/sw36193-6'
# Could not access /dls/labxchem/data/sw36193/sw36193-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw36193/sw36193-3'
# Could not access /dls/labxchem/data/lb28595/lb28595-11: [Errno 13] Permission denied: '/dls/labxchem/data/lb28595/lb28595-11'
# Could not access /dls/labxchem/data/lb35190/lb35190-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb35190/lb35190-1'
# Could not access /dls/labxchem/data/lb33144/lb33144-2: [Errno 13] Permission denied: '/dls/labxchem/data/lb33144/lb33144-2'
# Could not access /dls/labxchem/data/lb33144/lb33144-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb33144/lb33144-1'
# Could not access /dls/labxchem/data/lb34252/lb34252-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb34252/lb34252-1'
# Could not access /dls/labxchem/data/sw33704/sw33704-26: [Errno 13] Permission denied: '/dls/labxchem/data/sw33704/sw33704-26'
# Could not access /dls/labxchem/data/sw33704/sw33704-29: [Errno 13] Permission denied: '/dls/labxchem/data/sw33704/sw33704-29'
# Could not access /dls/labxchem/data/sw33704/sw33704-24: [Errno 13] Permission denied: '/dls/labxchem/data/sw33704/sw33704-24'
# Could not access /dls/labxchem/data/sw33704/sw33704-23: [Errno 13] Permission denied: '/dls/labxchem/data/sw33704/sw33704-23'
# Could not access /dls/labxchem/data/sw33704/sw33704-14: [Errno 13] Permission denied: '/dls/labxchem/data/sw33704/sw33704-14'
# Could not access /dls/labxchem/data/lb36896/lb36896-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb36896/lb36896-1'
# Could not access /dls/labxchem/data/lb36896/lb36896-8: [Errno 13] Permission denied: '/dls/labxchem/data/lb36896/lb36896-8'
# Could not access /dls/labxchem/data/lb36896/lb36896-5: [Errno 13] Permission denied: '/dls/labxchem/data/lb36896/lb36896-5'
# Could not access /dls/labxchem/data/lb36896/lb36896-9: [Errno 13] Permission denied: '/dls/labxchem/data/lb36896/lb36896-9'
# Could not access /dls/labxchem/data/lb36896/lb36896-2: [Errno 13] Permission denied: '/dls/labxchem/data/lb36896/lb36896-2'
# Could not access /dls/labxchem/data/sw33743/sw33743-11: [Errno 13] Permission denied: '/dls/labxchem/data/sw33743/sw33743-11'
# Could not access /dls/labxchem/data/sw33743/sw33743-13: [Errno 13] Permission denied: '/dls/labxchem/data/sw33743/sw33743-13'
# Could not access /dls/labxchem/data/sw35809/sw35809-12: [Errno 13] Permission denied: '/dls/labxchem/data/sw35809/sw35809-12'
# Could not access /dls/labxchem/data/sw35809/sw35809-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw35809/sw35809-1'
# Could not access /dls/labxchem/data/sw35809/sw35809-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw35809/sw35809-5'
# Could not access /dls/labxchem/data/sw35809/sw35809-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw35809/sw35809-3'
# Could not access /dls/labxchem/data/sw35809/sw35809-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw35809/sw35809-9'
# Could not access /dls/labxchem/data/sw35809/sw35809-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw35809/sw35809-7'
# Could not access /dls/labxchem/data/sw41417/sw41417-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw41417/sw41417-1'
# Could not access /dls/labxchem/data/sw41417/sw41417-2: [Errno 13] Permission denied: '/dls/labxchem/data/sw41417/sw41417-2'
# Could not access /dls/labxchem/data/sw37406/sw37406-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw37406/sw37406-3'
# Could not access /dls/labxchem/data/sw37406/sw37406-13: [Errno 13] Permission denied: '/dls/labxchem/data/sw37406/sw37406-13'
# Could not access /dls/labxchem/data/sw37406/sw37406-10: [Errno 13] Permission denied: '/dls/labxchem/data/sw37406/sw37406-10'
# Could not access /dls/labxchem/data/sw37406/sw37406-11: [Errno 13] Permission denied: '/dls/labxchem/data/sw37406/sw37406-11'
# Could not access /dls/labxchem/data/sw37406/sw37406-8: [Errno 13] Permission denied: '/dls/labxchem/data/sw37406/sw37406-8'
# Could not access /dls/labxchem/data/sw37406/sw37406-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw37406/sw37406-6'
# Could not access /dls/labxchem/data/sw37406/sw37406-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw37406/sw37406-1'
# Could not access /dls/labxchem/data/sw37406/sw37406-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw37406/sw37406-5'
# Could not access /dls/labxchem/data/sw35529/sw35529-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw35529/sw35529-1'
# Could not access /dls/labxchem/data/sw35529/sw35529-2: [Errno 13] Permission denied: '/dls/labxchem/data/sw35529/sw35529-2'
# Could not access /dls/labxchem/data/sw35529/sw35529-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw35529/sw35529-5'
# Could not access /dls/labxchem/data/sw35529/sw35529-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw35529/sw35529-7'
# Could not access /dls/labxchem/data/sw35529/sw35529-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw35529/sw35529-6'
# Could not access /dls/labxchem/data/lb34817/lb34817-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb34817/lb34817-1'
# Could not access /dls/labxchem/data/sw37448/sw37448-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw37448/sw37448-3'
# Could not access /dls/labxchem/data/sw37448/sw37448-10: [Errno 13] Permission denied: '/dls/labxchem/data/sw37448/sw37448-10'
# Could not access /dls/labxchem/data/sw37448/sw37448-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw37448/sw37448-6'
# Could not access /dls/labxchem/data/sw37448/sw37448-8: [Errno 13] Permission denied: '/dls/labxchem/data/sw37448/sw37448-8'
# Could not access /dls/labxchem/data/sw37448/sw37448-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw37448/sw37448-1'
# Could not access /dls/labxchem/data/in37331/in37331-5: [Errno 13] Permission denied: '/dls/labxchem/data/in37331/in37331-5'
# Could not access /dls/labxchem/data/in37331/in37331-3: [Errno 13] Permission denied: '/dls/labxchem/data/in37331/in37331-3'
# Could not access /dls/labxchem/data/in37331/in37331-4: [Errno 13] Permission denied: '/dls/labxchem/data/in37331/in37331-4'
# Could not access /dls/labxchem/data/in37331/in37331-1: [Errno 13] Permission denied: '/dls/labxchem/data/in37331/in37331-1'
# Could not access /dls/labxchem/data/lb38129/lb38129-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb38129/lb38129-1'
# Could not access /dls/labxchem/data/lb30665/lb30665-11: [Errno 13] Permission denied: '/dls/labxchem/data/lb30665/lb30665-11'
# Could not access /dls/labxchem/data/lb30665/lb30665-8: [Errno 13] Permission denied: '/dls/labxchem/data/lb30665/lb30665-8'
# Could not access /dls/labxchem/data/lb30665/lb30665-10: [Errno 13] Permission denied: '/dls/labxchem/data/lb30665/lb30665-10'
# Could not access /dls/labxchem/data/lb30665/lb30665-9: [Errno 13] Permission denied: '/dls/labxchem/data/lb30665/lb30665-9'
# Could not access /dls/labxchem/data/lb30665/lb30665-5: [Errno 13] Permission denied: '/dls/labxchem/data/lb30665/lb30665-5'
# Could not access /dls/labxchem/data/sw35385/sw35385-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw35385/sw35385-6'
# Could not access /dls/labxchem/data/sw35385/sw35385-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw35385/sw35385-1'
# Could not access /dls/labxchem/data/sw35385/sw35385-4: [Errno 13] Permission denied: '/dls/labxchem/data/sw35385/sw35385-4'
# Could not access /dls/labxchem/data/sw35385/sw35385-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw35385/sw35385-3'
# Could not access /dls/labxchem/data/sw38836/sw38836-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw38836/sw38836-3'
# Could not access /dls/labxchem/data/sw38836/sw38836-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw38836/sw38836-1'
# Could not access /dls/labxchem/data/sw35395/sw35395-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw35395/sw35395-1'
# Could not access /dls/labxchem/data/sw39006/sw39006-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw39006/sw39006-1'
# Could not access /dls/labxchem/data/sw39006/sw39006-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw39006/sw39006-3'
# Could not access /dls/labxchem/data/sw37131/sw37131-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw37131/sw37131-3'
# Could not access /dls/labxchem/data/sw37131/sw37131-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw37131/sw37131-1'
# Could not access /dls/labxchem/data/sw37131/sw37131-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw37131/sw37131-6'
# Could not access /dls/labxchem/data/sw37131/sw37131-4: [Errno 13] Permission denied: '/dls/labxchem/data/sw37131/sw37131-4'
# Could not access /dls/labxchem/data/lb36923/lb36923-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb36923/lb36923-1'
# Could not access /dls/labxchem/data/sw42203/sw42203-13: [Errno 13] Permission denied: '/dls/labxchem/data/sw42203/sw42203-13'
# Could not access /dls/labxchem/data/sw42203/sw42203-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw42203/sw42203-9'
# Could not access /dls/labxchem/data/sw42203/sw42203-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw42203/sw42203-1'
# Could not access /dls/labxchem/data/sw42203/sw42203-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw42203/sw42203-6'
# Could not access /dls/labxchem/data/sw42203/sw42203-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw42203/sw42203-5'
# Could not access /dls/labxchem/data/sw42203/sw42203-11: [Errno 13] Permission denied: '/dls/labxchem/data/sw42203/sw42203-11'
# Could not access /dls/labxchem/data/lb33200/lb33200-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb33200/lb33200-1'
# Could not access /dls/labxchem/data/sw39298/sw39298-11: [Errno 13] Permission denied: '/dls/labxchem/data/sw39298/sw39298-11'
# Could not access /dls/labxchem/data/sw39298/sw39298-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw39298/sw39298-5'
# Could not access /dls/labxchem/data/sw39298/sw39298-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw39298/sw39298-1'
# Could not access /dls/labxchem/data/sw39298/sw39298-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw39298/sw39298-7'
# Could not access /dls/labxchem/data/sw39298/sw39298-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw39298/sw39298-9'
# Could not access /dls/labxchem/data/sw39298/sw39298-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw39298/sw39298-3'
# Could not access /dls/labxchem/data/lb30488/lb30488-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb30488/lb30488-1'
# Could not access /dls/labxchem/data/sw37160/sw37160-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw37160/sw37160-6'
# Could not access /dls/labxchem/data/sw37160/sw37160-8: [Errno 13] Permission denied: '/dls/labxchem/data/sw37160/sw37160-8'
# Could not access /dls/labxchem/data/sw37160/sw37160-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw37160/sw37160-3'
# Could not access /dls/labxchem/data/sw37160/sw37160-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw37160/sw37160-1'
# Could not access /dls/labxchem/data/sw37160/sw37160-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw37160/sw37160-9'
# Could not access /dls/labxchem/data/lb36934/lb36934-2: [Errno 13] Permission denied: '/dls/labxchem/data/lb36934/lb36934-2'
# Could not access /dls/labxchem/data/lb36934/lb36934-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb36934/lb36934-1'
# Could not access /dls/labxchem/data/sw38996/sw38996-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw38996/sw38996-1'
# Could not access /dls/labxchem/data/sw38996/sw38996-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw38996/sw38996-3'
# Could not access /dls/labxchem/data/sw30864/sw30864-85: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-85'
# Could not access /dls/labxchem/data/sw30864/sw30864-87: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-87'
# Could not access /dls/labxchem/data/sw30864/sw30864-49: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-49'
# Could not access /dls/labxchem/data/sw30864/sw30864-17: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-17'
# Could not access /dls/labxchem/data/sw30864/sw30864-70: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-70'
# Could not access /dls/labxchem/data/sw30864/sw30864-19: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-19'
# Could not access /dls/labxchem/data/sw30864/sw30864-35: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-35'
# Could not access /dls/labxchem/data/sw30864/sw30864-53: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-53'
# Could not access /dls/labxchem/data/sw30864/sw30864-12: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-12'
# Could not access /dls/labxchem/data/sw30864/sw30864-45: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-45'
# Could not access /dls/labxchem/data/sw30864/sw30864-51: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-51'
# Could not access /dls/labxchem/data/sw30864/sw30864-25: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-25'
# Could not access /dls/labxchem/data/sw30864/sw30864-37: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-37'
# Could not access /dls/labxchem/data/sw30864/sw30864-32: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-32'
# Could not access /dls/labxchem/data/sw30864/sw30864-79: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-79'
# Could not access /dls/labxchem/data/sw30864/sw30864-67: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-67'
# Could not access /dls/labxchem/data/sw30864/sw30864-47: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-47'
# Could not access /dls/labxchem/data/sw30864/sw30864-73: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-73'
# Could not access /dls/labxchem/data/sw30864/sw30864-59: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-59'
# Could not access /dls/labxchem/data/sw30864/sw30864-81: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-81'
# Could not access /dls/labxchem/data/sw30864/sw30864-28: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-28'
# Could not access /dls/labxchem/data/sw30864/sw30864-22: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-22'
# Could not access /dls/labxchem/data/sw30864/sw30864-13: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-13'
# Could not access /dls/labxchem/data/sw30864/sw30864-39: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-39'
# Could not access /dls/labxchem/data/sw30864/sw30864-27: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-27'
# Could not access /dls/labxchem/data/sw30864/sw30864-63: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-63'
# Could not access /dls/labxchem/data/sw30864/sw30864-75: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-75'
# Could not access /dls/labxchem/data/sw30864/sw30864-57: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-57'
# Could not access /dls/labxchem/data/sw30864/sw30864-61: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-61'
# Could not access /dls/labxchem/data/sw30864/sw30864-41: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-41'
# Could not access /dls/labxchem/data/sw30864/sw30864-83: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-83'
# Could not access /dls/labxchem/data/sw30864/sw30864-15: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-15'
# Could not access /dls/labxchem/data/sw30864/sw30864-43: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-43'
# Could not access /dls/labxchem/data/sw30864/sw30864-65: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-65'
# Could not access /dls/labxchem/data/sw30864/sw30864-77: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-77'
# Could not access /dls/labxchem/data/sw30864/sw30864-24: [Errno 13] Permission denied: '/dls/labxchem/data/sw30864/sw30864-24'
# Could not access /dls/labxchem/data/sw37072/sw37072-11: [Errno 13] Permission denied: '/dls/labxchem/data/sw37072/sw37072-11'
# Could not access /dls/labxchem/data/sw37072/sw37072-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw37072/sw37072-5'
# Could not access /dls/labxchem/data/sw37072/sw37072-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw37072/sw37072-7'
# Could not access /dls/labxchem/data/sw37072/sw37072-13: [Errno 13] Permission denied: '/dls/labxchem/data/sw37072/sw37072-13'
# Could not access /dls/labxchem/data/sw37072/sw37072-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw37072/sw37072-3'
# Could not access /dls/labxchem/data/sw37072/sw37072-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw37072/sw37072-9'
# Could not access /dls/labxchem/data/sw37072/sw37072-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw37072/sw37072-1'
# Could not access /dls/labxchem/data/sw37072/sw37072-15: [Errno 13] Permission denied: '/dls/labxchem/data/sw37072/sw37072-15'
# Could not access /dls/labxchem/data/sw39428/sw39428-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw39428/sw39428-3'
# Could not access /dls/labxchem/data/sw39428/sw39428-24: [Errno 13] Permission denied: '/dls/labxchem/data/sw39428/sw39428-24'
# Could not access /dls/labxchem/data/sw39428/sw39428-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw39428/sw39428-5'
# Could not access /dls/labxchem/data/sw39428/sw39428-23: [Errno 13] Permission denied: '/dls/labxchem/data/sw39428/sw39428-23'
# Could not access /dls/labxchem/data/sw39428/sw39428-18: [Errno 13] Permission denied: '/dls/labxchem/data/sw39428/sw39428-18'
# Could not access /dls/labxchem/data/sw39428/sw39428-14: [Errno 13] Permission denied: '/dls/labxchem/data/sw39428/sw39428-14'
# Could not access /dls/labxchem/data/sw39428/sw39428-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw39428/sw39428-6'
# Could not access /dls/labxchem/data/sw39428/sw39428-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw39428/sw39428-7'
# Could not access /dls/labxchem/data/sw39428/sw39428-16: [Errno 13] Permission denied: '/dls/labxchem/data/sw39428/sw39428-16'
# Could not access /dls/labxchem/data/sw39428/sw39428-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw39428/sw39428-1'
# Could not access /dls/labxchem/data/sw39428/sw39428-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw39428/sw39428-9'
# Could not access /dls/labxchem/data/sw39428/sw39428-15: [Errno 13] Permission denied: '/dls/labxchem/data/sw39428/sw39428-15'
# Could not access /dls/labxchem/data/sw39428/sw39428-8: [Errno 13] Permission denied: '/dls/labxchem/data/sw39428/sw39428-8'
# Could not access /dls/labxchem/data/lb34517/lb34517-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb34517/lb34517-1'
# Could not access /dls/labxchem/data/lb40171/lb40171-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb40171/lb40171-1'
# Could not access /dls/labxchem/data/lb25874/lb25874-17: [Errno 13] Permission denied: '/dls/labxchem/data/lb25874/lb25874-17'
# Could not access /dls/labxchem/data/lb29658/lb29658-57: [Errno 13] Permission denied: '/dls/labxchem/data/lb29658/lb29658-57'
# Could not access /dls/labxchem/data/lb29658/lb29658-52: [Errno 13] Permission denied: '/dls/labxchem/data/lb29658/lb29658-52'
# Could not access /dls/labxchem/data/lb29658/lb29658-58: [Errno 13] Permission denied: '/dls/labxchem/data/lb29658/lb29658-58'
# Could not access /dls/labxchem/data/lb29658/lb29658-49: [Errno 13] Permission denied: '/dls/labxchem/data/lb29658/lb29658-49'
# Could not access /dls/labxchem/data/lb29658/lb29658-59: [Errno 13] Permission denied: '/dls/labxchem/data/lb29658/lb29658-59'
# Could not access /dls/labxchem/data/lb29658/lb29658-48: [Errno 13] Permission denied: '/dls/labxchem/data/lb29658/lb29658-48'
# Could not access /dls/labxchem/data/lb29658/lb29658-50: [Errno 13] Permission denied: '/dls/labxchem/data/lb29658/lb29658-50'
# Could not access /dls/labxchem/data/lb29658/lb29658-51: [Errno 13] Permission denied: '/dls/labxchem/data/lb29658/lb29658-51'
# Could not access /dls/labxchem/data/lb30295/lb30295-9: [Errno 13] Permission denied: '/dls/labxchem/data/lb30295/lb30295-9'
# Could not access /dls/labxchem/data/lb30295/lb30295-7: [Errno 13] Permission denied: '/dls/labxchem/data/lb30295/lb30295-7'
# Could not access /dls/labxchem/data/lb30295/lb30295-30: [Errno 13] Permission denied: '/dls/labxchem/data/lb30295/lb30295-30'
# Could not access /dls/labxchem/data/lb30295/lb30295-45: [Errno 13] Permission denied: '/dls/labxchem/data/lb30295/lb30295-45'
# Could not access /dls/labxchem/data/lb30295/lb30295-40: [Errno 13] Permission denied: '/dls/labxchem/data/lb30295/lb30295-40'
# Could not access /dls/labxchem/data/lb30295/lb30295-8: [Errno 13] Permission denied: '/dls/labxchem/data/lb30295/lb30295-8'
# Could not access /dls/labxchem/data/lb30295/lb30295-32: [Errno 13] Permission denied: '/dls/labxchem/data/lb30295/lb30295-32'
# Could not access /dls/labxchem/data/lb30295/lb30295-36: [Errno 13] Permission denied: '/dls/labxchem/data/lb30295/lb30295-36'
# Could not access /dls/labxchem/data/lb30295/lb30295-41: [Errno 13] Permission denied: '/dls/labxchem/data/lb30295/lb30295-41'
# Could not access /dls/labxchem/data/lb30295/lb30295-54: [Errno 13] Permission denied: '/dls/labxchem/data/lb30295/lb30295-54'
# Could not access /dls/labxchem/data/lb30295/lb30295-42: [Errno 13] Permission denied: '/dls/labxchem/data/lb30295/lb30295-42'
# Could not access /dls/labxchem/data/lb30295/lb30295-31: [Errno 13] Permission denied: '/dls/labxchem/data/lb30295/lb30295-31'
# Could not access /dls/labxchem/data/lb25897/lb25897-22: [Errno 13] Permission denied: '/dls/labxchem/data/lb25897/lb25897-22'
# Could not access /dls/labxchem/data/lb29814/lb29814-12: [Errno 13] Permission denied: '/dls/labxchem/data/lb29814/lb29814-12'
# Could not access /dls/labxchem/data/lb29814/lb29814-20: [Errno 13] Permission denied: '/dls/labxchem/data/lb29814/lb29814-20'
# Could not access /dls/labxchem/data/lb29814/lb29814-19: [Errno 13] Permission denied: '/dls/labxchem/data/lb29814/lb29814-19'
# Could not access /dls/labxchem/data/lb29814/lb29814-13: [Errno 13] Permission denied: '/dls/labxchem/data/lb29814/lb29814-13'
# Could not access /dls/labxchem/data/lb29814/lb29814-21: [Errno 13] Permission denied: '/dls/labxchem/data/lb29814/lb29814-21'
# Could not access /dls/labxchem/data/lb29814/lb29814-18: [Errno 13] Permission denied: '/dls/labxchem/data/lb29814/lb29814-18'
# Could not access /dls/labxchem/data/lb34721/lb34721-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb34721/lb34721-1'
# Could not access /dls/labxchem/data/lb38067/lb38067-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb38067/lb38067-1'
# Could not access /dls/labxchem/data/lb38880/lb38880-2: [Errno 13] Permission denied: '/dls/labxchem/data/lb38880/lb38880-2'
# Could not access /dls/labxchem/data/lb38880/lb38880-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb38880/lb38880-1'
# Could not access /dls/labxchem/data/lb36570/lb36570-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb36570/lb36570-1'
# Could not access /dls/labxchem/data/sw35748/sw35748-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw35748/sw35748-7'
# Could not access /dls/labxchem/data/sw35748/sw35748-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw35748/sw35748-1'
# Could not access /dls/labxchem/data/sw35748/sw35748-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw35748/sw35748-6'
# Could not access /dls/labxchem/data/sw35748/sw35748-2: [Errno 13] Permission denied: '/dls/labxchem/data/sw35748/sw35748-2'
# Could not access /dls/labxchem/data/sw35748/sw35748-4: [Errno 13] Permission denied: '/dls/labxchem/data/sw35748/sw35748-4'
# Could not access /dls/labxchem/data/sw35748/sw35748-11: [Errno 13] Permission denied: '/dls/labxchem/data/sw35748/sw35748-11'
# Could not access /dls/labxchem/data/sw37362/sw37362-15: [Errno 13] Permission denied: '/dls/labxchem/data/sw37362/sw37362-15'
# Could not access /dls/labxchem/data/sw37362/sw37362-16: [Errno 13] Permission denied: '/dls/labxchem/data/sw37362/sw37362-16'
# Could not access /dls/labxchem/data/sw37362/sw37362-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw37362/sw37362-7'
# Could not access /dls/labxchem/data/sw37362/sw37362-25: [Errno 13] Permission denied: '/dls/labxchem/data/sw37362/sw37362-25'
# Could not access /dls/labxchem/data/sw37362/sw37362-10: [Errno 13] Permission denied: '/dls/labxchem/data/sw37362/sw37362-10'
# Could not access /dls/labxchem/data/sw37362/sw37362-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw37362/sw37362-1'
# Could not access /dls/labxchem/data/sw37362/sw37362-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw37362/sw37362-9'
# Could not access /dls/labxchem/data/sw37362/sw37362-20: [Errno 13] Permission denied: '/dls/labxchem/data/sw37362/sw37362-20'
# Could not access /dls/labxchem/data/sw37362/sw37362-13: [Errno 13] Permission denied: '/dls/labxchem/data/sw37362/sw37362-13'
# Could not access /dls/labxchem/data/sw37362/sw37362-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw37362/sw37362-3'
# Could not access /dls/labxchem/data/sw37362/sw37362-22: [Errno 13] Permission denied: '/dls/labxchem/data/sw37362/sw37362-22'
# Could not access /dls/labxchem/data/sw37362/sw37362-18: [Errno 13] Permission denied: '/dls/labxchem/data/sw37362/sw37362-18'
# Could not access /dls/labxchem/data/sw37362/sw37362-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw37362/sw37362-5'
# Could not access /dls/labxchem/data/lb36909/lb36909-9: [Errno 13] Permission denied: '/dls/labxchem/data/lb36909/lb36909-9'
# Could not access /dls/labxchem/data/lb36909/lb36909-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb36909/lb36909-1'
# Could not access /dls/labxchem/data/lb36909/lb36909-2: [Errno 13] Permission denied: '/dls/labxchem/data/lb36909/lb36909-2'
# Could not access /dls/labxchem/data/sw33973/sw33973-8: [Errno 13] Permission denied: '/dls/labxchem/data/sw33973/sw33973-8'
# Could not access /dls/labxchem/data/sw33973/sw33973-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw33973/sw33973-7'
# Could not access /dls/labxchem/data/sw38699/sw38699-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw38699/sw38699-3'
# Could not access /dls/labxchem/data/sw38699/sw38699-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw38699/sw38699-9'
# Could not access /dls/labxchem/data/sw38699/sw38699-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw38699/sw38699-1'
# Could not access /dls/labxchem/data/sw38699/sw38699-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw38699/sw38699-6'
# Could not access /dls/labxchem/data/sw38699/sw38699-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw38699/sw38699-5'
# Could not access /dls/labxchem/data/sw42458/sw42458-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw42458/sw42458-3'
# Could not access /dls/labxchem/data/sw42458/sw42458-2: [Errno 13] Permission denied: '/dls/labxchem/data/sw42458/sw42458-2'
# Could not access /dls/labxchem/data/sw42458/sw42458-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw42458/sw42458-1'
# Could not access /dls/labxchem/data/lb36493/lb36493-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb36493/lb36493-1'
# Could not access /dls/labxchem/data/lb39514/lb39514-11: [Errno 13] Permission denied: '/dls/labxchem/data/lb39514/lb39514-11'
# Could not access /dls/labxchem/data/lb39514/lb39514-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb39514/lb39514-1'
# Could not access /dls/labxchem/data/sw38774/sw38774-16: [Errno 13] Permission denied: '/dls/labxchem/data/sw38774/sw38774-16'
# Could not access /dls/labxchem/data/sw38774/sw38774-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw38774/sw38774-1'
# Could not access /dls/labxchem/data/sw38774/sw38774-10: [Errno 13] Permission denied: '/dls/labxchem/data/sw38774/sw38774-10'
# Could not access /dls/labxchem/data/sw38774/sw38774-8: [Errno 13] Permission denied: '/dls/labxchem/data/sw38774/sw38774-8'
# Could not access /dls/labxchem/data/sw38774/sw38774-11: [Errno 13] Permission denied: '/dls/labxchem/data/sw38774/sw38774-11'
# Could not access /dls/labxchem/data/sw38774/sw38774-14: [Errno 13] Permission denied: '/dls/labxchem/data/sw38774/sw38774-14'
# Could not access /dls/labxchem/data/sw38774/sw38774-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw38774/sw38774-3'
# Could not access /dls/labxchem/data/sw38774/sw38774-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw38774/sw38774-5'
# Could not access /dls/labxchem/data/sw38818/sw38818-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw38818/sw38818-5'
# Could not access /dls/labxchem/data/sw38818/sw38818-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw38818/sw38818-1'
# Could not access /dls/labxchem/data/sw38818/sw38818-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw38818/sw38818-6'
# Could not access /dls/labxchem/data/sw38818/sw38818-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw38818/sw38818-3'
# Could not access /dls/labxchem/data/lb34408/lb34408-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb34408/lb34408-1'
# Could not access /dls/labxchem/data/lb31306/lb31306-6: [Errno 13] Permission denied: '/dls/labxchem/data/lb31306/lb31306-6'
# Could not access /dls/labxchem/data/lb31306/lb31306-31: [Errno 13] Permission denied: '/dls/labxchem/data/lb31306/lb31306-31'
# Could not access /dls/labxchem/data/lb31306/lb31306-30: [Errno 13] Permission denied: '/dls/labxchem/data/lb31306/lb31306-30'
# Could not access /dls/labxchem/data/lb31306/lb31306-15: [Errno 13] Permission denied: '/dls/labxchem/data/lb31306/lb31306-15'
# Could not access /dls/labxchem/data/lb31306/lb31306-16: [Errno 13] Permission denied: '/dls/labxchem/data/lb31306/lb31306-16'
# Could not access /dls/labxchem/data/lb31306/lb31306-37: [Errno 13] Permission denied: '/dls/labxchem/data/lb31306/lb31306-37'
# Could not access /dls/labxchem/data/lb31306/lb31306-44: [Errno 13] Permission denied: '/dls/labxchem/data/lb31306/lb31306-44'
# Could not access /dls/labxchem/data/lb31306/lb31306-20: [Errno 13] Permission denied: '/dls/labxchem/data/lb31306/lb31306-20'
# Could not access /dls/labxchem/data/lb31306/lb31306-43: [Errno 13] Permission denied: '/dls/labxchem/data/lb31306/lb31306-43'
# Could not access /dls/labxchem/data/lb36191/lb36191-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb36191/lb36191-1'
# Could not access /dls/labxchem/data/lb36191/lb36191-2: [Errno 13] Permission denied: '/dls/labxchem/data/lb36191/lb36191-2'
# Could not access /dls/labxchem/data/lb27963/lb27963-63: [Errno 13] Permission denied: '/dls/labxchem/data/lb27963/lb27963-63'
# Could not access /dls/labxchem/data/lb27963/lb27963-59: [Errno 13] Permission denied: '/dls/labxchem/data/lb27963/lb27963-59'
# Could not access /dls/labxchem/data/sw37546/sw37546-8: [Errno 13] Permission denied: '/dls/labxchem/data/sw37546/sw37546-8'
# Could not access /dls/labxchem/data/sw37546/sw37546-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw37546/sw37546-5'
# Could not access /dls/labxchem/data/sw37546/sw37546-13: [Errno 13] Permission denied: '/dls/labxchem/data/sw37546/sw37546-13'
# Could not access /dls/labxchem/data/sw37546/sw37546-11: [Errno 13] Permission denied: '/dls/labxchem/data/sw37546/sw37546-11'
# Could not access /dls/labxchem/data/sw37546/sw37546-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw37546/sw37546-1'
# Could not access /dls/labxchem/data/sw37546/sw37546-4: [Errno 13] Permission denied: '/dls/labxchem/data/sw37546/sw37546-4'
# Could not access /dls/labxchem/data/sw37546/sw37546-2: [Errno 13] Permission denied: '/dls/labxchem/data/sw37546/sw37546-2'
# Could not access /dls/labxchem/data/lb37024/lb37024-8: [Errno 13] Permission denied: '/dls/labxchem/data/lb37024/lb37024-8'
# Could not access /dls/labxchem/data/lb37024/lb37024-9: [Errno 13] Permission denied: '/dls/labxchem/data/lb37024/lb37024-9'
# Could not access /dls/labxchem/data/lb37024/lb37024-2: [Errno 13] Permission denied: '/dls/labxchem/data/lb37024/lb37024-2'
# Could not access /dls/labxchem/data/lb37024/lb37024-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb37024/lb37024-1'
# Could not access /dls/labxchem/data/lb31458/lb31458-2: [Errno 13] Permission denied: '/dls/labxchem/data/lb31458/lb31458-2'
# Could not access /dls/labxchem/data/sw36182/sw36182-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw36182/sw36182-6'
# Could not access /dls/labxchem/data/sw36182/sw36182-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw36182/sw36182-9'
# Could not access /dls/labxchem/data/sw36182/sw36182-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw36182/sw36182-3'
# Could not access /dls/labxchem/data/sw36182/sw36182-10: [Errno 13] Permission denied: '/dls/labxchem/data/sw36182/sw36182-10'
# Could not access /dls/labxchem/data/sw36182/sw36182-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw36182/sw36182-1'
# Could not access /dls/labxchem/data/sw36182/sw36182-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw36182/sw36182-5'
# Could not access /dls/labxchem/data/lb32958/lb32958-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb32958/lb32958-1'
# Could not access /dls/labxchem/data/lb32958/lb32958-2: [Errno 13] Permission denied: '/dls/labxchem/data/lb32958/lb32958-2'
# Could not access /dls/labxchem/data/lb32958/lb32958-8: [Errno 13] Permission denied: '/dls/labxchem/data/lb32958/lb32958-8'
# Could not access /dls/labxchem/data/lb32958/lb32958-9: [Errno 13] Permission denied: '/dls/labxchem/data/lb32958/lb32958-9'
# Could not access /dls/labxchem/data/lb32958/lb32958-3: [Errno 13] Permission denied: '/dls/labxchem/data/lb32958/lb32958-3'
# Could not access /dls/labxchem/data/lb32958/lb32958-4: [Errno 13] Permission denied: '/dls/labxchem/data/lb32958/lb32958-4'
# Could not access /dls/labxchem/data/sw34239/sw34239-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw34239/sw34239-3'
# Could not access /dls/labxchem/data/sw34239/sw34239-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw34239/sw34239-9'
# Could not access /dls/labxchem/data/sw34239/sw34239-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw34239/sw34239-1'
# Could not access /dls/labxchem/data/sw34239/sw34239-6: [Errno 13] Permission denied: '/dls/labxchem/data/sw34239/sw34239-6'
# Could not access /dls/labxchem/data/sw34239/sw34239-10: [Errno 13] Permission denied: '/dls/labxchem/data/sw34239/sw34239-10'
# Could not access /dls/labxchem/data/sw34239/sw34239-13: [Errno 13] Permission denied: '/dls/labxchem/data/sw34239/sw34239-13'
# Could not access /dls/labxchem/data/sw34239/sw34239-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw34239/sw34239-5'
# Could not access /dls/labxchem/data/sw33741/sw33741-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw33741/sw33741-1'
# Could not access /dls/labxchem/data/sw33741/sw33741-10: [Errno 13] Permission denied: '/dls/labxchem/data/sw33741/sw33741-10'
# Could not access /dls/labxchem/data/sw42343/sw42343-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw42343/sw42343-1'
# Could not access /dls/labxchem/data/sw42343/sw42343-2: [Errno 13] Permission denied: '/dls/labxchem/data/sw42343/sw42343-2'
# Could not access /dls/labxchem/data/lb35354/lb35354-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb35354/lb35354-1'
# Could not access /dls/labxchem/data/sw32415/sw32415-23: [Errno 13] Permission denied: '/dls/labxchem/data/sw32415/sw32415-23'
# Could not access /dls/labxchem/data/sw32415/sw32415-26: [Errno 13] Permission denied: '/dls/labxchem/data/sw32415/sw32415-26'
# Could not access /dls/labxchem/data/sw32415/sw32415-20: [Errno 13] Permission denied: '/dls/labxchem/data/sw32415/sw32415-20'
# Could not access /dls/labxchem/data/sw32415/sw32415-18: [Errno 13] Permission denied: '/dls/labxchem/data/sw32415/sw32415-18'
# Could not access /dls/labxchem/data/sw32415/sw32415-24: [Errno 13] Permission denied: '/dls/labxchem/data/sw32415/sw32415-24'
# Could not access /dls/labxchem/data/sw32415/sw32415-17: [Errno 13] Permission denied: '/dls/labxchem/data/sw32415/sw32415-17'
# Could not access /dls/labxchem/data/lb39203/lb39203-1: [Errno 13] Permission denied: '/dls/labxchem/data/lb39203/lb39203-1'
# Could not access /dls/labxchem/data/sw41075/sw41075-1: [Errno 13] Permission denied: '/dls/labxchem/data/sw41075/sw41075-1'
# Could not access /dls/labxchem/data/sw41075/sw41075-15: [Errno 13] Permission denied: '/dls/labxchem/data/sw41075/sw41075-15'
# Could not access /dls/labxchem/data/sw41075/sw41075-7: [Errno 13] Permission denied: '/dls/labxchem/data/sw41075/sw41075-7'
# Could not access /dls/labxchem/data/sw41075/sw41075-12: [Errno 13] Permission denied: '/dls/labxchem/data/sw41075/sw41075-12'
# Could not access /dls/labxchem/data/sw41075/sw41075-5: [Errno 13] Permission denied: '/dls/labxchem/data/sw41075/sw41075-5'
# Could not access /dls/labxchem/data/sw41075/sw41075-10: [Errno 13] Permission denied: '/dls/labxchem/data/sw41075/sw41075-10'
# Could not access /dls/labxchem/data/sw41075/sw41075-9: [Errno 13] Permission denied: '/dls/labxchem/data/sw41075/sw41075-9'
# Could not access /dls/labxchem/data/sw41075/sw41075-3: [Errno 13] Permission denied: '/dls/labxchem/data/sw41075/sw41075-3'
# Could not access /dls/labxchem/data/lb30602/lb30602-88: [Errno 13] Permission denied: '/dls/labxchem/data/lb30602/lb30602-88'
# Could not access /dls/labxchem/data/lb30602/lb30602-58: [Errno 13] Permission denied: '/dls/labxchem/data/lb30602/lb30602-58'
# Could not access /dls/labxchem/data/lb30602/lb30602-90: [Errno 13] Permission denied: '/dls/labxchem/data/lb30602/lb30602-90'
# Could not access /dls/labxchem/data/lb30602/lb30602-108: [Errno 13] Permission denied: '/dls/labxchem/data/lb30602/lb30602-108'
# Could not access /dls/labxchem/data/lb30602/lb30602-91: [Errno 13] Permission denied: '/dls/labxchem/data/lb30602/lb30602-91'
# Could not access /dls/labxchem/data/lb30602/lb30602-57: [Errno 13] Permission denied: '/dls/labxchem/data/lb30602/lb30602-57'
# Could not access /dls/labxchem/data/lb30602/lb30602-84: [Errno 13] Permission denied: '/dls/labxchem/data/lb30602/lb30602-84'
# Could not access /dls/labxchem/data/lb30602/lb30602-93: [Errno 13] Permission denied: '/dls/labxchem/data/lb30602/lb30602-93'
# Could not access /dls/labxchem/data/lb30602/lb30602-92: [Errno 13] Permission denied: '/dls/labxchem/data/lb30602/lb30602-92'
# Could not access /dls/labxchem/data/lb30602/lb30602-86: [Errno 13] Permission denied: '/dls/labxchem/data/lb30602/lb30602-86'
# Could not access /dls/labxchem/data/lb30602/lb30602-56: [Errno 13] Permission denied: '/dls/labxchem/data/lb30602/lb30602-56'
# Could not access /dls/labxchem/data/lb28724/lb28724-12: [Errno 13] Permission denied: '/dls/labxchem/data/lb28724/lb28724-12'
# Could not access /dls/labxchem/data/lb28724/lb28724-11: [Errno 13] Permission denied: '/dls/labxchem/data/lb28724/lb28724-11'
# Could not access /dls/labxchem/data/lb28724/lb28724-9: [Errno 13] Permission denied: '/dls/labxchem/data/lb28724/lb28724-9'
# Could not access /dls/labxchem/data/lb28724/lb28724-8: [Errno 13] Permission denied: '/dls/labxchem/data/lb28724/lb28724-8'

# %%
print( len(results))
print( results[:5])
# Out:
# 26530
# [PosixPath('/dls/labxchem/data/lb18145/lb18145-270/processing/analysis/model_building/A71EV2A-x1405'), PosixPath('/dls/labxchem/data/lb18145/lb18145-270/processing/analysis/model_building/A71EV2A-x3136'), PosixPath('/dls/labxchem/data/lb18145/lb18145-270/processing/analysis/model_building/A71EV2A-x0964'), PosixPath('/dls/labxchem/data/lb18145/lb18145-270/processing/analysis/model_building/A71EV2A-x0885'), PosixPath('/dls/labxchem/data/lb18145/lb18145-270/processing/analysis/model_building/A71EV2A-x0020')]

# %%
processed_results  = [ {"proj": path.parents[-5].name, 
                        "sesh": path.parents[-6].name, 
                        "dataset": path.name, 
                        "protID": re.match("^[a-zA-Z0-9]+", path.name).group()  } 
                        for path in results]
print( f"I.e. Processed Results: {processed_results[1]}")
print( len( processed_results ))
# Out:
# I.e. Processed Results: {'proj': 'lb18145', 'sesh': 'lb18145-270', 'dataset': 'A71EV2A-x3136', 'protID': 'A71EV2A'}
# 26530

# %%
import re
protIDs = set( [ item["protID"] for item in processed_results] )
sessions =  set( [ item["sesh"] for item in processed_results if re.match( ".*ev2a.*",item["protID"] , re.IGNORECASE )])
match_protIDs =  set( [ item["protID"] for item in processed_results if re.match( ".*ev2a.*",item["protID"] , re.IGNORECASE )])

protID_sesh_dict = { protID:  set() for protID in match_protIDs } 
for item in processed_results:
    if re.match( ".*ev2a.*",item["protID"] , re.IGNORECASE ):
        protID_sesh_dict[ item["protID"] ].add( item["sesh"] )
print( f"Current proteins that I have access to: {protIDs}")
print( f"Sessions with EV2A in their protein name: {sessions}")
print( f"Corresponding protein ids: {match_protIDs}" )
print( "\nProtein ID: Sessions")
for key, value in protID_sesh_dict.items() :
    print("\t", key, value)

rootdir = "/dls/labxchem/data"

paths_for_sesh_of_interest = { protID:  []  for protID in match_protIDs }
for key, value in protID_sesh_dict.items() :
    for sesh in value:
        proj = sesh.split("-")[0]
        paths_for_sesh_of_interest[key].append( f"{rootdir}/{proj}/{sesh}")

print( paths_for_sesh_of_interest)
# Out:
# Current proteins that I have access to: {'XX01ZVNS2B', 'XX01D2VNS2BA', 'D68EV3CPROB', 'QQ01D2VNS2BA', 'A71EV2A', 'A71EV2AC110A', 'Mpro', 'A71EV2AZ'}
# Sessions with EV2A in their protein name: {'lb32627-66', 'lb18145-270', 'lb32627-406', 'lb32627-352'}
# Corresponding protein ids: {'A71EV2AC110A', 'A71EV2A', 'A71EV2AZ'}
#
# Protein ID: Sessions
# 	 A71EV2AC110A {'lb32627-406'}
# 	 A71EV2A {'lb32627-66', 'lb18145-270'}
# 	 A71EV2AZ {'lb32627-352'}
# {'A71EV2AC110A': ['/dls/labxchem/data/lb32627/lb32627-406'], 'A71EV2A': ['/dls/labxchem/data/lb32627/lb32627-66', '/dls/labxchem/data/lb18145/lb18145-270'], 'A71EV2AZ': ['/dls/labxchem/data/lb32627/lb32627-352']}

# %% [markdown]
# ---

# %% [markdown]
# ## ID Datasets that have been Manually Curated

# %%
sessions = {'A71EV2AC110A': ['/dls/labxchem/data/lb32627/lb32627-406'], 
 'A71EV2A': ['/dls/labxchem/data/lb32627/lb32627-66', '/dls/labxchem/data/lb18145/lb18145-270'], 
 'A71EV2AZ': ['/dls/labxchem/data/lb32627/lb32627-352']}

dataset_canon_path = "/processing/analysis/model_building/"

# %% [markdown]
# analysis/pandda-inspect-events.csv
# -  Ligand confidence
#     - IF "high" ->

# %% [markdown]
# ### I.e.

# %%
import pandas as pd
