# %% [markdown]
# ## Description
# ### This notebook contains code used to identify the data of interest, and consolidate it into one folder, which will be the base for future analysis.
#
#
# <details open>
# <summary> Sources of Data Duplicates </summary>
#
# - Batch Duplicates
#
#     This occurs when one protein crystal - fragment pair is diffracted more than one time. Each time, a specific new protein crystal datasetID and new compound batchID for the fragment is used.
#
# </details>

# %% [markdown]
# ### Extract Apo Proteins
#
# <details open>
# <summary> <ins> <strong> Steps: </strong> </ins> </summary>
#
# - Look at soakdb
#
#     - Identify apo datasets
#
# - Get Dimple files for them
#
#
# <details>

# %% [markdown]
# ### Extact Ensemble Models and ensemble-ground_protein
#
# Reasoning:
#
# - Ensemble ground protein wil have more refinement than the apo solely
#
# <details open>
# <summary> <ins><strong> Steps: </strong> </ins> </summary>
#
# - Look at the list of datasets in fragalysis
#
# - Look for those in dls
#
# </details>
