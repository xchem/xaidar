# %% [markdown]
# # **<p align="center"> Crystal Contacts </p>**
#
# ## <ins> Description </ins>
# ### The goal of this notebook is to be able to filter between "hits" and "misses". In other words, the goal is to identify the protein crystal contact surfaces, find ligands found within these areas, and deem them artifacts of crystallography (misses) rather than real binders. <br> In addition, this notebook aims at performing an initial exploration of these ligands to induce polymerization based on inter-protein interactions.
#
# <details open>
# <summary> <font size="6"> <ins>Key Points 2 </ins> </font> </summary>
#
# - bulletpoint1
#
# -  bulletpoint1
#
# - [link]()
#
# - image1: <img src="" width = 50%>
#
# </details>
#
# </br>
#
# <details open>
# <summary> <font size = "6"> <ins> Key Points 2 </ins> </font> </summary>
#
# - `bulletpoint1`
#
#
# - `bulletpoint2`
#
#
#
# </details>
#
# </br>

# %% [markdown]
# ---

# %%
# Load Key Libraries
from pathlib import Path
rootdir = Path("../../../..").resolve()
import sys
sys.path.insert(0, str(rootdir) )
from typing import Callable, Generator

import gemmi 
import parasail
import numpy as np
from rdkit import Chem
import matplotlib.pyplot as plt

from xaidar.data.molecModels import loadPDB
from xaidar.data.molecModels import get_pdb_stats, sele_pdb, sele_Lig, get_res_CoM
from xaidar.data.molecModels import flatten_pdb, sele_AA, createPDB, get_atom_coord

# %% [markdown]
# ## Bullet point 1
#
# - ### Subpoint 1.1
