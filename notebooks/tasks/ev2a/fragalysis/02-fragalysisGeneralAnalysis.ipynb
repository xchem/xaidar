# %% [markdown]
# # **<p align="center"> Fragalysis General Data Analysis </p>**
#
# ## <ins> Description </ins>
# ### Dowloaded different data type folders (`zips`) from fragalysis, consolidated data into one unique folder without duplicates (`concat`), and transfered data to Wilson Cluster for Analysis.
#
# <details open>
# <summary> <font size="6"> <ins>Overall Goal:</ins> </font> </summary>
#
# - <ins> Identify Data Idiosyncracies</ins>, patterns and exceptions (e.g. how many protein chains per `.pdb` )
#
# - <ins> Extract Main Metadata about data quality </ins>, consistency, etc.
#
#
# </details>
#
# </br>
#
#
# <details open>
# <summary> <font size="6"> <ins>Specific Goals: </ins> </font> </summary>
#
# - Look at Proteins
#
#     - Per pdb:
#
#         - How many protein chains?
#
#         - Same sequence protein? Same conformation? Same chain IDs?
#
#     - Between pdbs
#
#         - Are proteins aligned in the same site?
#
#         - Is there a pattern for .pdb between them?
#
# - Look at ligands
#
# - Look at ligand - proteins
#
#
#
# </details>
#
# </br>

# %% [markdown]
# ---

# %% [markdown]
# ## Bullet point 1
#
# - ### Subpoint 1.1
