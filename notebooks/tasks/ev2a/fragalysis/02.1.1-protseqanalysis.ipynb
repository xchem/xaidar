# %% [markdown]
# # **<p align="center"> Protein Sequence Analysis  </p>**
#
# ## <ins> Description </ins>
# ### Main goal is to look at all the pdb file types in the fragalysis datasets, and look at the protein sequences
#
# <details open>
# <summary> <font size="6"> <ins> Main Steps</ins> </font> </summary>
#
# - All PDBs and prtein-wide analysis
#
#     - Extract all the different protein chains from all the different pdb formats
#
#     - Keep a metadata pandas object, that links each chain to the specific `folder type`, `dataset`, `subset`, `file format`, and `chain id`.
#
#     - Get descriptives analytics:
#
#         - How many different sequences are there?
#
#         - What is the distribution of numbers
#
#         - How does this distribution relate to the metadata descriptives:
#
#             - Same sequence for the same descriptive (e.g. same file format?)
#
#         - Are there sequence duplicates in a pdb?
#
# - [link]()
#
# - image1: <img src="" width = 50%>
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## Bullet point 1
#
# - ### Subpoint 1.1
