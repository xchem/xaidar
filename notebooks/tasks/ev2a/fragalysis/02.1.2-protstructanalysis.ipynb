# %% [markdown]
# # **<p align="center"> PDB Structure Analysis </p>**
#
# ## <ins> Description </ins>
# ###
#
# <details open>
# <summary> <font size="6"> <ins>Key Points 2 </ins> </font> </summary>
#
# - bulletpoint1
#
# -  For within a pdb
#
#     - Are there ligand duplicates in the pdb? (e.g.)
#
#         - What types of duplicates exist?
#
#             - Bind in the same protein chain, in the same protein sequence, in the same location, with the same orientation, and the same altconf?
#
#             - Bind in differnt protein chains, in the same protein sequence, in the same location, with the same orientation, and the same altconf?
#
#             - Bind in differnt protein chains, in the different protein sequence, in the same location, with the different orientation, and the same altconf?
#
#             - ...
#
# - [link]()
#
# - image1: <img src="" width = 50%>
#
# </details>
#
# </br>
#
# <details open>
# <summary> <font size = "6"> <ins> Key Points 2 </ins> </font> </summary>
#
# - `bulletpoint1`
#
#
# - `bulletpoint2`
#
#
#
# </details>
#
# </br>

# %% [markdown]
# ---

# %% [markdown]
# ## Bullet point 1
#
# - ### Subpoint 1.1
