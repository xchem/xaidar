# %% [markdown]
# The goal is to explore the information related to the object keys, and their native associated file structure.

# %%
# Initialize notebook
import sys

from pathlib import Path
sys.path.insert(0, Path("../..").resolve().absolute().__str__() )

from xaidar.filesUtils import loadPickle

# %%
pd_rawSizesdir = Path( "../../../data/s3Sizes/pandda/raw")
xc_rawSizesdir = Path( "../../../data/s3Sizes/xchem/raw")

# %% [markdown]
# ## Look at File Structure Associated to Object Keys

# %% [markdown]
# ### Look at Sample of Object Keys Interactively

# %% [markdown]
# ###  - Bucket: PanDDA

# %%
# Get a list of fragments
lst_fragFiles = [file for file in  pd_rawSizesdir.iterdir() if file.is_file() ]

# %%
fragIdx = 0
fragFile = loadPickle( lst_fragFiles[fragIdx])

# %%
sampleIdx = 0

# %%
sampleSize = 10

for objKey in list( fragFile.keys() )[ sampleIdx*sampleSize : (sampleIdx+1)*sampleSize ]:
    print( objKey)
sampleIdx += 100
# sampleIdx = sampleIdx - 100*5
# Out:
# DAPD/shells/2.4176321837953445/log.json
# DAPD/processed_datasets/DAPD-x0726/1/rhofit/Hit_00_00_004.pdb
# DAPD/shells/2.2676321837953446/log.json
# DAPD/shells/2.3676321837953447/log.json
# DAPD/shells/2.567632183795345/log.json
# DAPD/shells/2.517632183795345/log.json
# DAPD/processed_datasets/DAPD-x0727/2/log.json
# DAPD/processed_datasets/DAPD-x0727/1/scores.json
# DAPD/shells/2.717632183795345/log.json
# DAPD/processed_datasets/DAPD-x0727/1/cut.ccp4

# %%
fragIdx += 1
fragFile = loadPickle( lst_fragFiles[fragIdx])
sampleIdx = 0

# %% [markdown]
# ###  - Bucket: xchem

# %%
# Get a list of fragments
lst_fragFiles = [file for file in  xc_rawSizesdir.iterdir() if file.is_file() ]

# %%
fragIdx = 0
fragFile = loadPickle( lst_fragFiles[fragIdx])

# %%
sampleIdx = 0

# %%
sampleSize = 10

for objKey in list( fragFile.keys() )[ sampleIdx*sampleSize : (sampleIdx+1)*sampleSize ]:
    print( objKey)
sampleIdx += 100
# sampleIdx = sampleIdx - 100*5
# Out:
# data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1071/DCP2B-x1071_1_/fast_dp/forkintegrate_array_job.po18261547.4
# data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1079/DCP2B-x1079_1_/xia2/dials-runP212121/xia2-working.phil
# data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1070/DCP2B-x1070_1_/xia2/dials-runP212121/automatic.xinfo
# data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1071/DCP2B-x1071_1_/fast_ep/P212121/7/2.5/sad_fa.pdb
# data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1069/DCP2B-x1069_2_/multi-xia2/dialsP212121/LogFiles/AUTOMATIC_DEFAULT_pointless.log
# data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1069/DCP2B-x1069_1_/fast_ep/P21221/1/3.0/sad_fa.hkl
# data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1092/DCP2B-x1092_1_/xia2/dials-run/xia2-working.phil
# data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1069/DCP2B-x1069_2_/multi-xia2/dialsP212121/DataFiles/xia2.mmcif
# data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1087/DCP2B-x1087_1_/xia2/3dii-runP212121/xia2-debug.txt
# data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1079/DCP2B-x1079_1_/xia2/dials-runP212121/xia2.error

# %%
fragIdx += 1
fragFile = loadPickle( lst_fragFiles[fragIdx])
sampleIdx = 0

# %% [markdown]
# ### - xchem : Dataset

# %%
fragFile = loadPickle( xc_rawSizesdir / "frag14_sizes.pkl")

# %%
sampleSize = 10
sampleIdx = 9294500// sampleSize

# %%
for objKey in list( fragFile.keys() )[ sampleIdx*sampleSize : (sampleIdx+1)*sampleSize ]:
    print( objKey)
sampleIdx += 10 * sampleSize
# sampleIdx = sampleIdx - 100*5
# Out:
# data/lb30852/lb30852-1/processing/lab36/ispyb/lb30852-1_2022-05-10_15-56-19_ispyb.csv
# data/lb32627/lb32627-1/processing/lab36/sqlite3.dll
# data/lb32627/lb32627-1/processing/lab36/SQLite3_StdCall.dll
# dataset/autoprocessing/70X/70X-x0049/70X-x0049.free.mtz
# data/lb30852/lb30852-1/processing/database/DataFileBackups/soakDBDataFile_20220512110714.sqlite
# dataset/autoprocessing/70X/70X-x0053/70X-x0053.log
# dataset/autoprocessing/70X/70X-x0052/70X-x0052.free.mtz
# dataset/autoprocessing/70X/70X-x0051/70X-x0051.log
# data/lb30852/lb30852-1/processing/database/DataFileBackups/soakDBDataFile_20220512110749.sqlite
# dataset/autoprocessing/70X/70X-x0055/70X-x0055.log

# %% [markdown]
# ### Get Name of Folders for the first 3 levels of the File System

# %%
bucketDirs = [pd_rawSizesdir, xc_rawSizesdir ]
bucketNames = ["pandda", "xchem"]
storeFolderNames = { dir: { "1stLevel" : set(), "2ndLevel" : set(), "3rdLevel" : set() } for dir in bucketNames }


for bucketDir, bucket in zip( bucketDirs, bucketNames ):
    for fragFilePath in bucketDir.iterdir():
        if fragFilePath.is_file():
            frag = loadPickle( fragFilePath )
            for objKey in frag.keys():
                objPath = objKey.split("/")
                storeFolderNames[bucket]["1stLevel"].add( objPath[0])
                if len(objPath) >= 2: storeFolderNames[bucket]["2ndLevel"].add(objPath[1])
                if len(objPath) >= 3: storeFolderNames[bucket]["3rdLevel"].add( objPath[2] )

# %%
for dir, values in storeFolderNames.items():
    print( f"List of Directories found in {dir} Bucket for:")
    for level, list in values.items():
        print( f"\t{level} - {sorted(list)}")
    print("\n")
# Out:
# List of Directories found in pandda Bucket for:
# 	1stLevel - ['70X', '70X.err', '70X.log', '70X.out', '70X.sh', '70X.singularity.sh', 'AAVNAR', 'AAVNAR.err', 'AAVNAR.log', 'AAVNAR.out', 'AAVNAR.sh', 'AAVNAR.singularity.sh', 'AA_VNAR_XF01', 'AA_VNAR_XF01.err', 'AA_VNAR_XF01.log', 'AA_VNAR_XF01.out', 'AA_VNAR_XF01.sh', 'AA_VNAR_XF01.singularity.sh', 'ACVR1A', 'ACVR1A.err', 'ACVR1A.log', 'ACVR1A.out', 'ACVR1A.sh', 'ACVR1A.singularity.sh', 'ATAD2A', 'ATAD2A.err', 'ATAD2A.log', 'ATAD2A.out', 'ATAD2A.sh', 'ATAD2A.singularity.sh', 'B2m', 'B2m.err', 'B2m.log', 'B2m.out', 'B2m.sh', 'B2m.singularity.sh', 'BKVP1', 'BKVP1.err', 'BKVP1.log', 'BKVP1.out', 'BKVP1.sh', 'BKVP1.singularity.sh', 'BKVP126', 'BKVP126.err', 'BKVP126.log', 'BKVP126.out', 'BKVP126.sh', 'BKVP126.singularity.sh', 'BRD1', 'BRD1.err', 'BRD1.log', 'BRD1.out', 'BRD1.sh', 'BRD1.singularity.sh', 'CD44MMA', 'CD44MMA.err', 'CD44MMA.log', 'CD44MMA.out', 'CD44MMA.sh', 'CD44MMA.singularity.sh', 'CD73', 'CD73.err', 'CD73.log', 'CD73.out', 'CD73.sh', 'CD73.singularity.sh', 'CD73mp', 'CD73mp.err', 'CD73mp.log', 'CD73mp.out', 'CD73mp.sh', 'CD73mp.singularity.sh', 'CYCK', 'CYCK.err', 'CYCK.log', 'CYCK.out', 'CYCK.sh', 'CYCK.singularity.sh', 'DAPD', 'DAPD.err', 'DAPD.log', 'DAPD.out', 'DAPD.sh', 'DAPD.singularity.sh', 'DCLRE1AA', 'DCLRE1AA.err', 'DCLRE1AA.log', 'DCLRE1AA.out', 'DCLRE1AA.sh', 'DCLRE1AA.singularity.sh', 'DCP2B', 'DCP2B.err', 'DCP2B.log', 'DCP2B.out', 'DCP2B.sh', 'DCP2B.singularity.sh', 'EBNA_A2', 'EBNA_A2.err', 'EBNA_A2.log', 'EBNA_A2.out', 'EBNA_A2.sh', 'EBNA_A2.singularity.sh', 'EBNA_T2', 'EBNA_T2.err', 'EBNA_T2.log', 'EBNA_T2.out', 'EBNA_T2.sh', 'EBNA_T2.singularity.sh', 'ERAP1', 'ERAP1.err', 'ERAP1.log', 'ERAP1.out', 'ERAP1.sh', 'ERAP1.singularity.sh', 'FALZA', 'FALZA.err', 'FALZA.log', 'FALZA.out', 'FALZA.sh', 'FALZA.singularity.sh', 'FabF_C164Q', 'FabF_C164Q.err', 'FabF_C164Q.log', 'FabF_C164Q.out', 'FabF_C164Q.sh', 'FabF_C164Q.singularity.sh', 'G13D', 'G13D.err', 'G13D.log', 'G13D.out', 'G13D.sh', 'G13D.singularity.sh', 'G7', 'G7.err', 'G7.log', 'G7.out', 'G7.sh', 'G7.singularity.sh', 'GALE', 'GALE.err', 'GALE.log', 'GALE.out', 'GALE.sh', 'GALE.singularity.sh', 'GN6S', 'GN6S.err', 'GN6S.log', 'GN6S.out', 'GN6S.sh', 'GN6S.singularity.sh', 'GluN1N2A', 'GluN1N2A.err', 'GluN1N2A.log', 'GluN1N2A.out', 'GluN1N2A.sh', 'GluN1N2A.singularity.sh', 'HAO1A', 'HAO1A.err', 'HAO1A.log', 'HAO1A.out', 'HAO1A.sh', 'HAO1A.singularity.sh', 'HARBD', 'HARBD.err', 'HARBD.log', 'HARBD.out', 'HARBD.sh', 'HARBD.singularity.sh', 'HEC1', 'HEC1.err', 'HEC1.log', 'HEC1.out', 'HEC1.sh', 'HEC1.singularity.sh', 'HPrP', 'HPrP.err', 'HPrP.log', 'HPrP.out', 'HPrP.sh', 'HPrP.singularity.sh', 'HSP90', 'HSP90.err', 'HSP90.log', 'HSP90.out', 'HSP90.sh', 'HSP90.singularity.sh', 'IAV', 'IAV.err', 'IAV.log', 'IAV.out', 'IAV.sh', 'IAV.singularity.sh', 'IDH1', 'IDH1.err', 'IDH1.log', 'IDH1.out', 'IDH1.sh', 'IDH1.singularity.sh', 'JMJD1BA', 
13385-67', 'lb13385-68', 'lb13385-69', 'lb13385-70', 'lb13385-71', 'lb13385-75', 'lb13385-76', 'lb13385-77', 'lb13385-78', 'lb13385-79', 'lb13385-80', 'lb13385-82', 'lb13385-83', 'lb13385-84', 'lb13385-85', 'lb13385-86', 'lb13385-87', 'lb13385-88', 'lb13385-89', 'lb13385-90', 'lb13385-93', 'lb13385-94', 'lb13385-95', 'lb13385-96', 'lb13385-97', 'lb13385-98', 'lb13385-99', 'lb14320-1', 'lb14320-12', 'lb14320-17', 'lb14320-5', 'lb14320-8', 'lb14321-1', 'lb14321-2', 'lb14321-4', 'lb14321-5', 'lb14321-8', 'lb14331-1', 'lb14331-12', 'lb14331-3', 'lb14331-5', 'lb14379-1', 'lb14379-12', 'lb14379-13', 'lb14379-4', 'lb14379-6', 'lb14379-8', 'lb14607-1', 'lb14607-3', 'lb14607-6', 'lb15510-1', 'lb15510-4', 'lb15511-1', 'lb15511-5', 'lb15511-7', 'lb15511-8', 'lb15523-1', 'lb15523-4', 'lb15523-5', 'lb15523-7', 'lb15647-1', 'lb15647-3', 'lb15647-4', 'lb15649-1', 'lb15649-10', 'lb15649-3', 'lb15649-6', 'lb15649-8', 'lb15751-1', 'lb15751-3', 'lb15956-1', 'lb15956-10', 'lb15956-3', 'lb15956-5', 'lb15956-8', 'lb16813-1', 'lb16813-3', 'lb16814-1', 'lb16814-4', 'lb16815-1', 'lb16816-1', 'lb16816-3', 'lb16946-1', 'lb16946-3', 'lb16949-10', 'lb16949-11', 'lb16949-12', 'lb16949-14', 'lb16949-17', 'lb16949-18', 'lb16949-19', 'lb16949-2', 'lb16949-21', 'lb16949-23', 'lb16949-3', 'lb16949-4', 'lb16949-7', 'lb16949-8', 'lb16949-9', 'lb16974-1', 'lb16974-3', 'lb16977-1', 'lb16978-1', 'lb16978-3', 'lb16979-1', 'lb16979-3', 'lb16980-1', 'lb16980-3', 'lb16980-4', 'lb16980-6', 'lb16981-1', 'lb16981-3', 'lb16981-4', 'lb16981-7', 'lb16981-8', 'lb16988-1', 'lb16988-10', 'lb16988-4', 'lb16988-6', 'lb16988-8', 'lb16988-9', 'lb16993-1', 'lb16993-4', 'lb17334-1', 'lb17334 ...

# %% [markdown]
# ---

# %% [markdown]
# ### Total pandda files

# %%
# Check if there are no errors during the file type sizes processing
import re
pd_rawKeysdir = Path( "../../../data/s3ObjKeys/pandda/raw")
pd_rawSizesdir = Path( "../../../data/s3Sizes/pandda/raw")


def count( datadir, countFunction, filterFunction= lambda x: True):
    filesCount = 0
    for file in datadir.iterdir():
        if file.is_file() and filterFunction(file):
            temp = loadPickle(file)
            filesCount += countFunction(temp)
    return filesCount

pd_rawKeyscount = count(pd_rawKeysdir, lambda x: len(x["Content"][1:]))
pd_rawSizescount = count(pd_rawSizesdir, lambda x: len(x.keys()))

print(f"Total Object Key files in pandda: {pd_rawKeyscount}")
print(f"Total Object Size files in pandda: {pd_rawSizescount}")
# Out:
# Total Object Key files in pandda: 5115662
# Total Object Size files in pandda: 5115662

# %% [markdown]
# ## Total xchem files

# %%
import re
xc_rawKeysdir = Path( "../../../data/s3ObjKeys/xchem/raw")
xc_rawSizesdir = Path( "../../../data/s3Sizes/xchem/raw")


def count( datadir, countFunction, filterFunction= lambda x: True):
    filesCount = 0
    for file in datadir.iterdir():
        if file.is_file() and filterFunction(file):
            temp = loadPickle(file)
            filesCount += countFunction(temp)
    return filesCount

# xc_rawKeyscount = count(xc_rawKeysdir, lambda x: len(x["Content"][1:]))
xc_rawSizescount = count(xc_rawSizesdir, lambda x: len(x.keys()))

# print(f"Total Object Key files in xchem: {xc_rawKeyscount}")
print(f"Total Object Size files in xchem: {xc_rawSizescount}")
# Out:
# Total Object Size files in xchem: 129663907

# %% [markdown]
# ## Look at Root directories in Each Bucket

# %%
xchemRawKeysDir = Path("../../../data/s3ObjKeys/xchem/raw").resolve()
panddaRawKeysDir = Path("../../../data/s3ObjKeys/pandda/raw").resolve()

# %%
import re
lstRawKeysDir = [panddaRawKeysDir, xchemRawKeysDir]

rootNames = {"pandda": set(), "xchem": set() }
for dir, bucketName in zip( lstRawKeysDir, ["pandda", "xchem"] ):
    for fragPath in dir.iterdir():
        if fragPath.is_file():
            frag = loadPickle( fragPath )
            stRoots = set( [ path.split("/")[0] for path in frag["Content"][1:] if not re.search( "\.", path.split("/")[0]) ])
            rootNames[bucketName].update( stRoots)


            # print( sorted(list(stRoots)[:5]))
            # print( type( frag))
            # print( type( frag["Content"]))
            # print(  frag["Content"][:50])

    #         break
    # break

# %%
print( sorted(list(rootNames["pandda"]))[:100])
print( sorted(list(rootNames["xchem"]))[:100])
# Out:
# ['70X', 'AAVNAR', 'AA_VNAR_XF01', 'ACVR1A', 'ATAD2A', 'B2m', 'BKVP1', 'BKVP126', 'BRD1', 'CD44MMA', 'CD73', 'CD73mp', 'CYCK', 'DAPD', 'DCLRE1AA', 'DCP2B', 'EBNA_A2', 'EBNA_T2', 'ERAP1', 'FALZA', 'FabF_C164Q', 'G13D', 'G7', 'GALE', 'GN6S', 'GluN1N2A', 'HAO1A', 'HARBD', 'HEC1', 'HPrP', 'HSP90', 'IAV', 'IDH1', 'JMJD1BA', 'JMJD2AA', 'JMJD2DA', 'JOELS', 'KAT2B', 'KLHL7B', 'KdsA', 'LC_TbrB1', 'LchARH3', 'LmARS', 'M2', 'MACROD1A', 'MID2A', 'MUREECA', 'Mpro', 'NS3Hel', 'NSP15', 'NSP15_B', 'NSP16', 'NUDT21A', 'NUDT22A', 'NUDT4A', 'NUDT5A', 'NUDT7A', 'Nprot', 'OTUB2A', 'OXA10OTA', 'PARG', 'PDE5', 'PDK2', 'PGN_RS02895PGA', 'PHD2', 'PHIPA', 'PIF1', 'PKL1', 'PKM1', 'PP1', 'PRPB', 'PTP1B', 'PWWP_C64S', 'PaFEN_D4', 'PaPBP3', 'PlProwt', 'RECQL5', 'RECQL5A', 'RabC01', 'SETDB1', 'SHH', 'SHMT2A', 'SOCS2A', 'STAG1A', 'TBRUFPPS', 'TBXTA', 'TCRUFPPS', 'TMEMAB', 'TNCA', 'TRF1', 'TRIM2A', 'TbMDO', 'TbrB1', 'TcHRS', 'VP30ctd', 'XX02KALRNA', 'XX11RECQL5A', 'a7ACHBPm', 'mArh', 'macro']
# ['data', 'dataset']

# %%
frag = loadPickle( panddaRawKeysDir / "frag14.pkl")

panddaContent= {"level2": set(), "level3": set()}
print("pandda bucket example keys:")
for fragPath in panddaRawKeysDir.iterdir():
    frag = loadPickle( fragPath)
    idx = 0
    for key in frag["Content"][1:]:
        if len(key.split("/") ) >= 2: panddaContent["level2"].add( key.split("/")[1])
        if len(key.split("/") ) >= 3:panddaContent["level3"].add( key.split("/")[2])
        if idx <= 2:
            print("\t", key)
            idx +=1
        else: pass
# Out:
# pandda bucket example keys:
# 	 70X.err
# 	 70X.log
# 	 70X.out
# 	 DAPD/processed_datasets/DAPD-x0029/7/rhofit/Hit_00_00_003.pdb
# 	 DAPD/processed_datasets/DAPD-x0029/7/rhofit/Hit_00_00_004.pdb
# 	 DAPD/processed_datasets/DAPD-x0029/7/rhofit/Hit_00_00_005.pdb
# 	 DAPD/processed_datasets/DAPD-x0531/14/rhofit.lis
# 	 DAPD/processed_datasets/DAPD-x0531/14/rhofit/Hit_00_00_000.pdb
# 	 DAPD/processed_datasets/DAPD-x0531/14/rhofit/Hit_00_00_001.pdb
# 	 DCP2B/processed_datasets/DCP2B-x0369/ligand_files/FMOPL000050a_TMP/mol_1_conf_20_tmp_init.pdb
# 	 DCP2B/processed_datasets/DCP2B-x0369/ligand_files/FMOPL000050a_TMP/mol_1_conf_20_tmp_refmac_stage_0.log
# 	 DCP2B/processed_datasets/DCP2B-x0369/ligand_files/FMOPL000050a_TMP/mol_1_conf_20_tmp_refmac_stage_0.pdb
# 	 EBNA_T2/processed_datasets/EBNA_T2-x0169/1/scores.json
# 	 EBNA_T2/processed_datasets/EBNA_T2-x0169/1/truncated.ccp4
# 	 EBNA_T2/processed_datasets/EBNA_T2-x0169/2/ana_pdbmaps.log
# 	 FabF_C164Q/processed_datasets/FabF_C164Q-x0427/2/scores.json
# 	 FabF_C164Q/processed_datasets/FabF_C164Q-x0427/2/truncated.ccp4
# 	 FabF_C164Q/processed_datasets/FabF_C164Q-x0427/3/ana_pdbmaps.log
# 	 GALE/processed_datasets/GALE-x0334/ligand_files/Z1263714198_TMP/mol_1_conf_13_tmp_refmac_stage_0.mmcif
# 	 GALE/processed_datasets/GALE-x0334/ligand_files/Z1263714198_TMP/mol_1_conf_13_tmp_refmac_stage_0.pdb
# 	 GALE/processed_datasets/GALE-x0334/ligand_files/Z1263714198_TMP/mol_1_conf_14_tmp_init.pdb
# 	 GluN1N2A/processed_datasets/GluN1N2A-x0348/18/scores.json
# 	 GluN1N2A/processed_datasets/GluN1N2A-x0348/18/truncated.ccp4
# 	 GluN1N2A/processed_datasets/GluN1N2A-x0348/19/ana_pdbmaps.log
# 	 IDH1/processed_datasets/Apo-D1/20/masked.pdb
# 	 IDH1/processed_datasets/Apo-D1/20/truncated.ccp4
# 	 IDH1/processed_datasets/Apo-D1/21/cut.ccp4
# 	 IDH1/processed_datasets/IDH1-x0250/20/cut.ccp4
# 	 TbMDO/processed_datasets/TbMDO-x710/ligand_files/N13432a_TMP/mol_1_conf_12_tmp_refmac_stage_1.log
# 	 TcHRS/processed_datasets/TcHRS-x0201/ligand_files/DDD00771548_TMP/DDD00771548_mol_0_cod.pdb
# 	 TcHRS/processed_datasets/TcHRS-x0201/ligand_files/DDD00771548_TMP/DDD00771548_mol_0_cod.rst
# 	 TcHRS/processed_datasets/TcHRS-x0201/ligand_files/DDD00771548_TMP/inputSmiles.smi
# 	 BKVP1/processed_datasets/BKVP1-x0415/11/rhofit/Hit_00_00_000.pdb
# 	 BKVP1/processed_datasets/BKVP1-x0415/11/rhofit/Hit_00_00_001.pdb
# 	 BKVP1/processed_datasets/BKVP1-x0415/11/rhofit/Hit_00_00_002.pdb
# 	 XX02KALRNA/processed_datasets/XX02KALRNA-x0142/5/ligand.pickle
# 	 XX02KALRNA/processed_datasets/XX02KALRNA-x0142/5/log.json
# 	 XX02KALRNA/processed_datasets/XX02KALRNA-x0142/5/masked.pdb
# 	 XX11RECQL5A/processed_datasets/XX11RECQL5A-x0896/0/truncated.ccp4
# 	 XX11RECQL5A/processed_datasets/XX11RECQL5A-x0896/1/cut.ccp4
# 	 XX11RECQL5A/processed_datasets/XX11RECQL5A-x0896/1/masked.pdb
# 	 XX11RECQL5A/processed_datasets/XX11RECQL5A-x1315/XX11RECQL5A-x1315-z_map.native.ccp4
# 	 XX11RECQL5A/processed_datasets/XX11RECQL5A-x1315/ligand.smiles
# 	 XX11RECQL5A/processed_datasets/XX11RECQL5A-x1315/ligand_files/Z818732104.smiles
# 	 BKVP126/processed_datasets/BKVP126-x0686/BKVP126-x0686-event_1_1-BDC_0.51_map.native.ccp4
# 	 BKVP126/processed_datasets/BKVP126-x0686/BKVP126-x0686-pandda-input.mtz
# 	 BKVP126/processed_datasets/BKVP126-x0686/BKVP126-x0686-pandda-input.pdb
# 	 BRD1/processed_datasets/BRD1-x565/6/ana_pdbmaps.pdb
# 	 BRD1/processed_datasets/BRD1-x565/6/ana_pdbmaps_cluster.lis
# 	 BRD1/processed_datasets/BRD1-x565/6/ana_pdbmaps_cluster_001
# 	 CD73/processed_datasets/CD73-x0160/15/rhofit/Hit_00_00_005.pdb
# 	 CD73/processed_datasets/CD73-x0160/15/rhofit/Hit_00_00_006.pdb
# 	 CD73/processed_datasets/CD73-x0160/15/rhofit/Hit_00_00_007.pdb
# 	 CYCK/processed_datasets/CYCK-x0125/ligand_files/Z1506115273.pickle
# 	 CYCK/processed_datasets/CYCK-x0125/ligand_files/Z1506115273.png
# 	 CYCK/processed_datasets/CYCK-x0125/ligand_files/Z1506115273.smiles

# %%
lev1, lev2, lev3 = sorted(list(rootNames["pandda"]))[:], panddaContent["level2"], panddaContent["level3"]
print( f"First Level Contents: { lev1}")
print( f"Second Level Contents: { lev2 }")
print( f"Third Level Contents: { lev3}")
# Out:
NUDT22A-x0121', '1.451625034707712', 'GALE-x0655', 'AA_VNAR_XF01-x1058', 'PWWP_C64S-x0398', 'AA_VNAR_XF01-x1074', 'CD73-x0139', 'LchARH3-x0517', 'PWWP_C64S-x0313', 'PDE5-x0206', 'STAG1A-x0700', 'BKVP126-x0563', 'NSP15_B-x0370', 'NSP15-x0118', 'SHMT2A-x0940', 'NSP15_B-x0500', 'CD73-x0418', 'BKVP126-x0565', 'AAVNAR-XF01-x1239', 'PHIPA-x20592', 'NSP16-x0514', 'NS3Hel-x0186', '2.8498569051969285', 'PRPB-x0541', 'ERAP1-x0050', 'GluN1N2A-x0708', 'macro_EU-x0227', 'NS3Hel-x0176', 'BKVP126-x0287', 'macro_EU-x0569', 'HSP90-x0378', 'STAG1A-x0941', 'FabF_C164Q-x0693', 'VP30ctd-x0459', '2.2592934521231802', 'Mac1-x10107', 'Mac1-x10086', 'SHMT2A-x0342', 'SHMT2A-x1040', 'SHH-x307', 'CD44MMA-x0357', 'GluN1N2A-x0080', 'CYCK-x0638', 'LC_TbrB1-x0182', 'NUDT7A-x0071', 'EBNA_T2-x0339', 'ACVR1A-x1233', 'CD73-x0114', 'DCP2B-x0638', 'NSP15_B-x0283', 'CD73-x0350', 'Nprot-x1096', 'BKVP126-x0421', 'LchARH3-x0648', 'Gl ...

# %%
lookExample = True
datasetContent = {"level2":set(), "level3":set()}
frag = loadPickle( xchemRawKeysDir / "frag14.pkl")
for key in frag["Content"]:
    if key[:7] == "dataset":
        datasetContent["level2"].add( key.split("/")[1] )
        datasetContent["level3"].add( key.split("/")[2])
        if lookExample:
            print(f"Example of dataset key:{key}")
            lookExample = False

print(  datasetContent["level2"])
# print( type( frag["Content"][-10][:7]) )
# Out:
# Example of dataset key:dataset/autoprocessing/70X/70X-x0049/70X-x0049.free.mtz
# {'dimple', 'autoprocessing'}

# %%
print(  sorted(datasetContent["level3"]))
lenDataset, lenPandda = len(datasetContent["level3"]), len(rootNames["pandda"]) 
print( f"Dataset Number of datasets: { lenDataset }")
print( f"Pandda Number of datasets: {lenPandda}")

if datasetContent["level3"] == rootNames["pandda"]:
    print( "xchem dataset contains the same datasets as pandda bucket")
if datasetContent["level3"] != rootNames["pandda"]:
    print( "xchem dataset with NOT the same datasets as pandda")

matchDatasets = rootNames["pandda"] & datasetContent["level3"]
panddaMismatch = rootNames["pandda"] - matchDatasets
xchemDatasetMismatch = datasetContent["level3"]  - matchDatasets
numbMatchingDatasets = len( matchDatasets ) 
if numbMatchingDatasets == 103:
    print( "All pandda datasets exist in dataset")
else:
    print( f"Number of matched: {numbMatchingDatasets}")
    print( "Matched Datasets: ", sorted(matchDatasets) )
    print( f"Pandda missmatched Datasets: {len(panddaMismatch)} - {sorted(panddaMismatch) }")
    print( f"Xchem dataset missmatched Datasets: {len(xchemDatasetMismatch)} - {sorted(xchemDatasetMismatch) }")
# Out:
# ['70X', 'AASSA', 'AAVNAR', 'AAVNAR-XF01', 'AA_VNAR_XF01', 'ACVR1A', 'ADARB1A', 'ALAS2A', 'ALDH7A1A', 'APBE', 'ATAD2A', 'B2m', 'BC1960', 'BKVP1', 'BKVP126', 'BRD1', 'BRD4', 'CAMK1DA', 'CD44MMA', 'CD73', 'CD73mp', 'CD73p', 'CYCK', 'CtUTTG_GT24', 'CycT2', 'DAPD', 'DBDJBP1', 'DCLRE1AA', 'DCP2B', 'DHTKD1A', 'EBNA_A', 'EBNA_A2', 'EBNA_T', 'EBNA_T2', 'ECR', 'EPB41L3A', 'ERAP1', 'FALZA', 'FAM83BA', 'FIH', 'FabF_C164Q', 'G13D', 'GALE', 'GALK1A', 'GN6S', 'HAO1A', 'HARBD', 'HDAC6', 'HEC1', 'HERC2A', 'HPrP', 'HSET', 'HSP90', 'IAV-3P', 'IDH1', 'IMPA1A', 'INPP5DA', 'IRF4', 'JARID1BA', 'JMJD2AA', 'JOELS', 'KAT2B', 'KBTBD5A', 'KLHL7B', 'KPNF', 'KdsA', 'LC_TbrB1', 'LchARH3', 'LmARS', 'M2-1', 'MACROD1A', 'MID2A', 'MMGLU2', 'MPRO', 'MUREECA', 'Mac1', 'Mac1-Nuc', 'MerA', 'MmGluIITryps', 'Mpro', 'Mpro_Nterm', 'NS3Hel', 'NSP14', 'NSP15', 'NSP15_B', 'NSP16', 'NUDT21A', 'NUDT22A', 'NUDT4A', 'NUDT5A', 'NUDT7A', 'NUDT7A_CR_SL', 'NUDT7A_Crude', 'NUDT7_mpin', 'Nprot', 'OTUB2A', 'OXA10', 'OXA10OTA', 'PARG', 'PARP14A', 'PBP5', 'PCAFA', 'PDE5', 'PDK2', 'PGN_RS02895PGA', 'PHD2', 'PHIPA', 'PIF1', 'PKL1', 'PKM1', 'PP1', 'PRPB', 'PTP1B', 'PWWP_C64S', 'PaFEN_D4', 'PaPBP3', 'PlPro', 'PlProwt', 'PurC', 'R1', 'RBBP7A', 'RECQL5', 'RECQL5A', 'RabC01', 'RecQ1', 'RecQ1_DNA', 'SERC', 'SETDB1', 'SHH', 'SHMT2A', 'SOCS2A', 'STAG1A', 'TBXTA', 'TDP2', 'TMEMAB', 'TNCA', 'TRF1', 'TRIM16A', 'TRIM25PS', 'TRIM2A', 'TbMDO', 'TbTR', 'TbrB1', 'TcHRS', 'Tif6', 'USP8A', 'VIM2', 'VP30ctd', 'Vim2', 'XX02KALRNA', 'YEATS4A', 'acrb', 'gluk1', 'mArh', 'macro-combi', 'macro-thionuc', 'macro_EU', 'mkeap1', 'nsp13', 'smTGR', 'srta', 'tetra', 'unknown', 'zkmt']
# Dataset Number of datasets: 164
# Pandda Number of datasets: 103
# xchem dataset with NOT the same datasets as pandda
# Number of matched: 92
# Matched Datasets:  ['70X', 'AAVNAR', 'AA_VNAR_XF01', 'ACVR1A', 'ATAD2A', 'B2m', 'BKVP1', 'BKVP126', 'BRD1', 'CD44MMA', 'CD73', 'CD73mp', 'CYCK', 'DAPD', 'DCLRE1AA', 'DCP2B', 'EBNA_A2', 'EBNA_T2', 'ERAP1', 'FALZA', 'FabF_C164Q', 'G13D', 'GALE', 'GN6S', 'HAO1A', 'HARBD', 'HEC1', 'HPrP', 'HSP90', 'IDH1', 'JMJD2AA', 'JOELS', 'KAT2B', 'KLHL7B', 'KdsA', 'LC_TbrB1', 'LchARH3', 'LmARS', 'MACROD1A', 'MID2A', 'MUREECA', 'Mpro', 'NS3Hel', 'NSP15', 'NSP15_B', 'NSP16', 'NUDT21A', 'NUDT22A', 'NUDT4A', 'NUDT5A', 'NUDT7A', 'Nprot', 'OTUB2A', 'OXA10OTA', 'PARG', 'PDE5', 'PDK2', 'PGN_RS02895PGA', 'PHD2', 'PHIPA', 'PIF1', 'PKL1', 'PKM1', 'PP1', 'PRPB', 'PTP1B', 'PWWP_C64S', 'PaFEN_D4', 'PaPBP3', 'PlProwt', 'RECQL5', 'RECQL5A', 'RabC01', 'SETDB1', 'SHH', 'SHMT2A', 'SOCS2A', 'STAG1A', 'TBXTA', 'TMEMAB', 'TNCA', 'TRF1', 'TRIM2A', 'TbMDO', 'TbrB1', 'TcHRS', 'VP30ctd', 'XX02KALRNA', 'mArh', 'macro_EU', 'smTGR', 'zkmt']
# Pandda missmatched Datasets: 11 - ['G7', 'GluN1N2A', 'IAV', 'JMJD1BA', 'JMJD2DA', 'M2', 'TBRUFPPS', 'TCRUFPPS', 'XX11RECQL5A', 'a7ACHBPm', 'macro']
# Xchem dataset missmatched Datasets: 72 - ['AASSA', 'AAVNAR-XF01', 'ADARB1A', 'ALAS2A', 'ALDH7A1A', 'APBE', 'BC1960', 'BRD4', 'CAMK1DA', 'CD73p', 'CtUTTG_GT24', 'CycT2', 'DBDJBP1', 'DHTKD1A', 'EBNA_A', 'EBNA_T', 'ECR', 'EPB41L3A', 'FAM83BA', 'FIH', 'GALK1A', 'HDAC6', 'HERC2A', 'HSET', 'IAV-3P', 'IMPA1A', 'INPP5DA', 'IRF4', 'JARID1BA', 'KBTBD5A', 'KPNF', 'M2-1', 'MMGLU2', 'MPRO', 'Mac1', 'Mac1-Nuc', 'MerA', 'MmGluIITryps', 'Mpro_Nterm', 'NSP14', 'NUDT7A_CR_SL', 'NUDT7A_Crude', 'NUDT7_mpin', 'OXA10', 'PARP14A', 'PBP5', 'PCAFA', 'PlPro', 'PurC', 'R1', 'RBBP7A', 'RecQ1', 'RecQ1_DNA', 'SERC', 'TDP2', 'TRIM16A', 'TRIM25PS', 'TbTR', 'Tif6', 'USP8A', 'VIM2', 'Vim2', 'YEATS4A', 'acrb', 'gluk1', 'macro-combi', 'macro-thionuc', 'mkeap1', 'nsp13', 'srta', 'tetra', 'unknown']

# %%
for fragPath in xchemRawKeysDir.iterdir():
    frag = loadPickle( fragPath)
    for key in frag["Content"][1:]:
        print(key[:7])
        break
        if key[:7] == "dataset":
            print(key)  
            break
# Out:
# data/20
# data/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 4
#       2 frag = loadPickle( fragPath)
#       3 for key in frag["Content"][1:]:
# ----> 4     print(key[:7])
#       5     break
#       6     if key[:7] == "dataset":
#
# File d:\xaidar\.win-venv\Lib\site-packages\IPython\core\interactiveshell.py:3027, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3025 def write(data, *args, **kwargs):
#    3026     """Write data to both the original destination and the capture dictionary."""
# -> 3027     result = original_write(data, *args, **kwargs)
#    3028     if any(
#    3029         [
#    3030             self.display_pub.is_publishing,
#    (...)   3033         ]
#    3034     ):
#    3035         return result
#
# File d:\xaidar\.win-venv\Lib\site-packages\ipykernel\iostream.py:655, in OutStream.write(self, string)
#     647                     return
#     649             self.session.send(
#     650                 self.pub_thread,
#     651                 msg,
#     652                 ident=self.topic,
#     653             )
# --> 655 def write(self, string: str) -> Optional[int]:  # type:ignore[override]
#     656     """Write to current stream after encoding if necessary
#     657
#     658     Returns
#    (...)    662
#     663     """
#     664     parent = self.parent_header
#
# KeyboardInterrupt:

# %% [markdown]
# ## Looking At Sessions

# %%
# Get a List of Paths to Directories with Sessions Synthax -> st_sessions.pkl

from xaidar.filesUtils import loadPickle, savePyObj
import re


rawXCDir = Path( "../../../data/s3ObjKeys/xchem/raw")

sessionRegex = "^[a-z][a-z][0-9]+-[0-9]+$"
lstSessionDirs = set()

for fragFile in rawXCDir.iterdir():
    if fragFile.is_file():
        print( f"Loading file: {fragFile.name}")
        frag = loadPickle( fragFile)
        keys = frag["Content"][1:]
        for objKey in keys:
            pathLst = objKey.split("/")
            path = ""
            for item in pathLst:
                path += "/" + item
                if re.search( sessionRegex, item):
                    lstSessionDirs.add( path[1:] )

savePyObj( lstSessionDirs, Path( "./lst_sessions.pkl"))

# %%
# checking for sessions without canonical synthax
import re
rawXCDir = Path( "../../../data/s3ObjKeys/xchem/raw")

sessionRegex = "^[a-z][a-z][0-9]+-[0-9]+$"

lstWeirdSeshNames = set()

for fragFile in rawXCDir.iterdir():
    if fragFile.is_file():
        print( f"Loading file: {fragFile.name}")
        frag = loadPickle( fragFile)
        keys = frag["Content"][1:]
        for objKey in keys:
            session = objKey.split("/")[2]
            if not re.search( sessionRegex, session):
                lstWeirdSeshNames.add( session )
# Out:
# Loading file: frag1.pkl
# Loading file: frag10.pkl
# Loading file: frag11.pkl
# Loading file: frag12.pkl
# Loading file: frag13.pkl
# Loading file: frag14.pkl
# Loading file: frag2.pkl
# Loading file: frag3.pkl
# Loading file: frag4.pkl
# Loading file: frag5.pkl
# Loading file: frag6.pkl
# Loading file: frag7.pkl
# Loading file: frag8.pkl
# Loading file: frag9.pkl

# %%
print( len( lstWeirdSeshNames))
print( lstWeirdSeshNames)
# Out:
# 164
# {'APBE', 'TRIM2A', 'IMPA1A', 'USP8A', 'Vim2', 'STAG1A', 'ACVR1A', 'KAT2B', 'CAMK1DA', 'MMGLU2', 'B2m', 'zkmt', 'EBNA_A', 'MACROD1A', 'TRIM16A', 'MmGluIITryps', 'OXA10', 'SOCS2A', 'PBP5', 'PlProwt', 'TBXTA', 'NUDT7_mpin', 'BKVP126', 'PARP14A', 'FIH', 'VP30ctd', '70X', 'DCP2B', 'TbTR', 'PWWP_C64S', 'NSP14', 'TRF1', 'AA_VNAR_XF01', 'ADARB1A', 'EBNA_T', 'MerA', 'NSP15_B', 'AASSA', 'CYCK', 'FALZA', 'TbrB1', 'R1', 'BKVP1', 'PaPBP3', 'NSP16', 'macro_EU', 'ECR', 'macro-thionuc', 'gluk1', 'RECQL5', 'HEC1', 'Tif6', 'VIM2', 'LC_TbrB1', 'PTP1B', 'HDAC6', 'HERC2A', 'MUREECA', 'ALAS2A', 'IAV-3P', 'MID2A', 'PP1', 'KPNF', 'BRD1', 'NUDT7A_Crude', 'RecQ1', 'PHIPA', 'NUDT7A', 'DBDJBP1', 'CD73p', 'CD73', 'IRF4', 'RecQ1_DNA', 'RECQL5A', 'JMJD2AA', 'DCLRE1AA', 'Mpro', 'ERAP1', 'mkeap1', 'NSP15', 'NS3Hel', 'XX02KALRNA', 'RBBP7A', 'PKM1', 'YEATS4A', 'INPP5DA', 'DHTKD1A', 'Nprot', 'NUDT22A', 'srta', 'PaFEN_D4', 'TRIM25PS', 'NUDT5A', 'macro-combi', 'FAM83BA', 'AAVNAR-XF01', 'TDP2', 'Mac1-Nuc', 'ALDH7A1A', 'GN6S', 'CycT2', 'ATAD2A', 'EPB41L3A', 'CtUTTG_GT24', 'LchARH3', 'IDH1', 'SERC', 'NUDT7A_CR_SL', 'PIF1', 'GALE', 'smTGR', 'PKL1', 'OXA10OTA', 'EBNA_A2', 'JARID1BA', 'PurC', 'G13D', 'DAPD', 'mArh', 'LmARS', 'PlPro', 'M2-1', 'SHH', 'EBNA_T2', 'PDK2', 'CD73mp', 'FabF_C164Q', 'SHMT2A', 'HPrP', 'OTUB2A', 'GALK1A', 'acrb', 'Mpro_Nterm', 'PHD2', 'Mac1', 'KBTBD5A', 'AAVNAR', 'HSP90', 'CD44MMA', 'HSET', 'unknown', 'TMEMAB', 'TbMDO', 'NUDT4A', 'PDE5', 'RabC01', 'PGN_RS02895PGA', 'NUDT21A', 'BRD4', 'KdsA', 'MPRO', 'HARBD', 'HAO1A', 'TNCA', 'TcHRS', 'JOELS', 'KLHL7B', 'PARG', 'nsp13', 'SETDB1', 'PRPB', 'BC1960', 'PCAFA', 'tetra'}

# %%
# Load Sessions Librart
from xaidar.filesUtils import loadPickle
lstSessionDirs = loadPickle( Path( "./lst_sessions.pkl"))
lstSessionDirs = sorted( list(lstSessionDirs))

# %%
# Select Normal Sessions (data/{year}/{lbxxx-x} or data/{year}/{lbxxx-x}/ )

# Get a list of paths split into elements of a list
lst_lstSessions = [ path.split("/") for path in lstSessionDirs if len(path.split("/")) <= 5 ]
print( f"Number of Normal Sessions: {len(lst_lstSessions ) }")
lst_lstSessions 

# Look at sessions with Subsessions
print("")
seshWsesh = [ path[2] for path in lst_lstSessions if len(path) == 5  ]
subSeshs = [ path[-1] for path in lst_lstSessions if len(path) == 5  ]
seshWseshDict = { sesh: [ path[-1] for path in lst_lstSessions if path[2] == sesh] for sesh in seshWsesh }
print( subSeshs)
print( f"Sessions with Subsession:")
for key, value in seshWseshDict.items(): print( "\t",key, value)

# Get only names rather than paths for Sessions
lst_SeshNames = [ path[-1] for path in lst_lstSessions ]
set_SeshNames = set( lst_SeshNames)
# print( "Session Names:")
# for name in lst_SeshNames: print( f"\t{name}")
print("")
print( f"There are no repeating session names between years: { sorted(list(set(lst_SeshNames)) )== sorted(lst_SeshNames)}")
print( f"Length of Set: {len( list(set( lst_SeshNames)))}")
print( f"Length of List: {len(lst_SeshNames)}")
print( f"Content of lst_SeshNames: {lst_SeshNames[:2]}" )
# Out:
# Number of Normal Sessions: 750
#
# ['lb13320-15', 'lb13320-17', 'lb13320-18', 'lb13320-2', 'lb13320-4', 'lb13320-7', 'lb13320-9', 'nt11175-118', 'lb13385-112', 'lb25874-11', 'lb25874-8']
# Sessions with Subsession:
# 	 lb13320-1 ['lb13320-1', 'lb13320-15', 'lb13320-17', 'lb13320-18', 'lb13320-2', 'lb13320-4', 'lb13320-7', 'lb13320-9']
# 	 lb13385-1 ['lb13385-1', 'nt11175-118']
# 	 lb13385-64 ['lb13385-64', 'lb13385-112']
# 	 lb25874-6 ['lb25874-6', 'lb25874-11', 'lb25874-8']
#
# There are no repeating session names between years: True
# Length of Set: 750
# Length of List: 750
# Content of lst_SeshNames: ['lb13308-1', 'lb13308-2']

# %%
sizesDir = Path( "../../../data/s3Sizes/xchem/raw")
testFilePath = [ item for item in sizesDir.iterdir() if item.is_file() ][0]
fragFile = loadPickle( testFilePath)

# %%
print( type(fragFile) )
print( len(list(fragFile.keys())) )
print(list(fragFile.keys())[:5] )
print(list(fragFile.values())[:5] )
# Out:
# <class 'dict'>
# 10000976
# ['data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1069/DCP2B-x1069_2_/fast_ep/P2212/3/2.3/sad_fa.res', 'data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1085/DCP2B-x1085_1_/autoPROC/ap-run/aimless_late.log', 'data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1069/DCP2B-x1069_2_/multi-xia2/3diiP212121/LogFiles/AUTOMATIC_DEFAULT_aimless.html', 'data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1069/DCP2B-x1069_1_/fast_ep/P2122/1/3.0/sad_fa.pdb', 'data/2017/lb18145-43/processing/old/lb13385-112/processed/DCP2B/DCP2B-x1093/DCP2B-x1093_1_/fast_dp/INTEGRATE.HKL']
# [498, 142179, 1405197, 429, 260856]

# %%
sizesDir = Path( "../../../data/s3Sizes/xchem/raw")

sizesDict = { key : [] for key in lst_SeshNames }
seshWsesh_set = set(seshWsesh)
subSeshs_set = set( subSeshs)

for fragFile in list(sizesDir.iterdir()):
    if fragFile.is_file():
        print( f"Loading file: {fragFile.name}")
        frag = loadPickle( fragFile)

        for objKey, size in frag.items():
            pathLst = objKey.split("/")
            session = pathLst[2]
            if session in set_SeshNames:     
                sizesDict[session].append(size)
                if session in seshWsesh_set:
                    subsession = pathLst[4]
                    if subsession in subSeshs_set:
                        sizesDict[subsession].append(size)
# Out:
# Loading file: frag10_sizes.pkl
# Loading file: frag11_sizes.pkl
# Loading file: frag12_sizes.pkl
# Loading file: frag13_sizes.pkl
# Loading file: frag14_sizes.pkl
# Loading file: frag1_sizes.pkl
# Loading file: frag2_sizes.pkl
# Loading file: frag3_sizes.pkl
# Loading file: frag4_sizes.pkl
# Loading file: frag5_sizes.pkl
# Loading file: frag6_sizes.pkl
# Loading file: frag7_sizes.pkl
# Loading file: frag8_sizes.pkl
# Loading file: frag9_sizes.pkl

# %%
print( len(     [ key for key, value in  sizesDict.items() if len(value) > 0]))
loadedKeys = [ key for key, value in  sizesDict.items() if len(value) > 0]

print( len(sizesDict.keys()) )
print( len( sizesDict.values() ) )
print(  list( sizesDict.values() )[0]) 
print( set( [ type(value)  for lst in sizesDict.values()  for value in lst ])) 
 39804, 4403, 2679, 4403, 35606, 233, 46437, 55815, 731684, 3691964, 39804, 29813, 8260, 39804, 633711, 6228, 35606, 315, 39804, 4403, 232, 621, 633711, 305, 3603088, 1346, 1292, 47032, 2679, 6672, 731684, 452, 452, 4403, 39804, 56410, 8233, 29813, 2679, 35606, 452, 55994, 46862, 233, 731684, 6756, 1582, 195, 1954, 1730, 633711, 39804, 626, 5355, 731684, 37368148, 729740, 1942, 731684, 562, 6152, 2679, 29813, 39804, 457, 4403, 6747, 3650144, 6765, 452, 731684, 8275, 39804, 233, 46607, 3179176, 46097, 29214, 35042, 46300, 2679, 4403, 2679, 55563, 233, 1170660, 452, 731684, 39804, 6714, 633708, 8239, 5872, 46097, 46470, 2679, 29966, 55733, 1568, 6758, 4403, 321, 1309652, 633708, 39804, 452, 731684, 46117, 6312, 8275, 4403, 305, 2679, 4403, 30906, 233, 457, 6792, 3649192, 452, 731684, 2221600, 633708, 1565, 8234, 39804, 29813, 5997, 2679, 4403, 633708, 6693, 8270, 319, 1582, 55105, 452, 39804, 2221600, 731684, 1349, 7839, 633711, 1954, 731684, 46117, 39804, 1982, 457, 729740, 5365, 729740, 29813, 8089, 8270, 4976, 39804, 4404, 951, 457, 39804, 1414, 3730, 731684, 731684, 4428, 5000, 3768, 39804, 39804, 457, 846, 729740, 29813, 29813, 6513, 2679, 46947, 40867, 247, 7480, 29435, 1576, 731684, 319, 6693, 6574, 29813, 1349, 29813, 39804, 56308, 606, 4403, 41055, 605, 55105, 6764, 492, 6805, 307, 47032, 5595284, 562, 186, 731684, 39804, 6225, 492, 47032, 2679, 6595, 29813, 233, 41055, 30906, 633711, 6806, 4403, 5595284, 620, 1455, 731684, 39 ...
# {<class 'str'>, <class 'int'>}

# %%
print( len( sizesDict[loadedKeys[idx] ]))
idx += 1
# Out:
# 664801

# %%
# Get session sizes:
newseshSizesDict = { key: [ size for size in value  if type(size) == int] for key, value in sizesDict.items() } #

# %%
seshSizes = { key: sum(value) for key, value in newseshSizesDict.items() }

print( len(seshSizes.values()) )
list(seshSizes.values())[:4]
# Out:
# 750
# [56075700224, 905, 1009727936299, 86038430616]

# %%
import matplotlib.pyplot as plt
import numpy as np

mean , median = np.mean(list(seshSizes.values()) ), np.median( list(seshSizes.values()))
print( f"Mean: { mean}")
print( f"Median: {  median }")

plt.figure()

plt.boxplot( seshSizes.values(), vert = False)
plt.title( "Distribution of Sizes of Session Directories")
plt.xlabel( "Size of Session Directories (bytes)")
# Out:
# Mean: 211396156318.78934
# Median: 524476.0
# Text(0.5, 0, 'Size of Session Directories (bytes)')

# %%
# Get Years to match sessions
import re
rawXCDir = Path( "../../../data/s3ObjKeys/xchem/raw")

sessionRegex = "^[a-z][a-z][0-9]+-[0-9]+$"

lstWeirdSeshNames = set()

for fragFile in rawXCDir.iterdir():
    if fragFile.is_file():
        print( f"Loading file: {fragFile.name}")
        frag = loadPickle( fragFile)
        keys = frag["Content"][1:]
        for objKey in keys:
            session = objKey.split("/")[2]
            if not re.search( sessionRegex, session):
                lstWeirdSeshNames.add( session )
