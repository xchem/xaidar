# %% [markdown]
# #
#
# - General Protein
#
#     - Overall Protein Attributes ()
#
#     -
#
# - General

# %%
import pandas as pd


ligandIdentifiers = ["Ligand Name", "SMILES", "InChI", "FilePath"]
datasetIdentifiers = ["Dataset Name", "DOI", "FilePath"]
ligandTable = pd.DataFrame(columns =[  "Ligand Conformation", *ligandIdentifiers, *datasetIdentifiers,  ] )


interactionTable = pd.DataFrame(columns =[ "Ligand Atom ID", "Protein Atom ID", "Distance (A)", "Orientation", "Ligand Functional Group", "Amino Acid",*ligandIdentifiers, *datasetIdentifiers, "Interaction Type", "Interaction Atoms", "Interaction Details" ] )

# %% [markdown]
# ## Creating the Fragment Library Table
#
# Associated Tasks and Analysis:
#
# - Count Number of Proteins that binds to

# %%
# Unique Datapoint Element: Library Name + Fragment Identifiers (There can be the same fragments in different libraries ) 

fragmentIdentifiers = ["Fragment Name", "SMILES", "InChI", "FilePath"]
fragLibraryTable = pd.DataFrame(columns =[ "Library Name", fragmentIdentifiers, "List of Bound Proteins",  ] )

# %% [markdown]
# ## Creating Interaction Table
#
# #### Steps:
#
#  - Pick a radius of interest (i.e. 10 Angstorms from any of the ligand atoms)
#
#  - For each atom in the ligand, identify the closest atom for each amino acid with the radius of interest
#
#  -
